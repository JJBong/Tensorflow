# %%
# -*- coding: utf-8 -*-
"""
Teaching a machine to play an Atari game (Pacman by default) by implementing
a 1-step Q-learning with TFLearn, TensorFlow and OpenAI gym environment. The
algorithm is described in "Asynchronous Methods for Deep Reinforcement Learning"
paper. OpenAI's gym environment is used here for providing the Atari game
environment for handling games logic and states. This example is originally
adapted from Corey Lynch's repo (url below).
Requirements:
    - gym environment (pip install gym)
    - gym Atari environment (pip install gym[atari])
References:
    - Asynchronous Methods for Deep Reinforcement Learning. Mnih et al, 2015.
Links:
    - Paper: http://arxiv.org/pdf/1602.01783v1.pdf
    - OpenAI's gym: https://gym.openai.com/
    - Original Repo: https://github.com/coreylynch/async-rl
"""
from __future__ import division, print_function, absolute_import

import threading
import random
import numpy as np
import time
from skimage.transform import resize
from skimage.color import rgb2gray
from collections import deque

import gym
import tensorflow as tf
import tflearn

# Fix for TF 0.12
try:
    writer_summary = tf.summary.FileWriter
    merge_all_summaries = tf.summary.merge_all
    histogram_summary = tf.summary.histogram
    scalar_summary = tf.summary.scalar
except Exception:
    writer_summary = tf.train.SummaryWriter
    merge_all_summaries = tf.merge_all_summaries
    histogram_summary = tf.histogram_summary
    scalar_summary = tf.scalar_summary

# Change that value to test instead of train
testing = False
# Model path (to load when testing)
test_model_path = '/Users/jubong/git/Tensorflow/Untitled/breakout.ckpt'
# Atari game to learn
# You can also try: 'Breakout-v0', 'Pong-v0', 'SpaceInvaders-v0', ...
game = 'Breakout-v0'
# Learning threads
n_threads = 8

# =============================
#   Training Parameters
# =============================
# Max training steps
TMAX = 80000000
# Current training step
T = 0
# Consecutive screen frames when performing training
action_repeat = 4
# Async gradient update frequency of each learning thread
I_AsyncUpdate = 5
# Timestep to reset the target network
I_target = 40000
# Learning rate
learning_rate = 0.001
# Reward discount rate
gamma = 0.99
# Number of timesteps to anneal epsilon
anneal_epsilon_timesteps = 400000

# =============================
#   Utils Parameters
# =============================
# Display or not gym evironment screens
show_training = True
# Directory for storing tensorboard summaries
summary_dir = '/tmp/tflearn_logs/'
summary_interval = 100
checkpoint_path = 'breakout.ckpt'
checkpoint_interval = 2000
# Number of episodes to run gym evaluation
num_eval_episodes = 100


# =============================
#   TFLearn Deep Q Network
# =============================
def build_dqn(num_actions, action_repeat):
    """
    Building a DQN.
    """
    inputs = tf.placeholder(tf.float32, [None, action_repeat, 84, 84])
    # Inputs shape: [batch, channel, height, width] need to be changed into
    # shape [batch, height, width, channel]
    net = tf.transpose(inputs, [0, 2, 3, 1])
    net = tflearn.conv_2d(net, 32, 8, strides=4, activation='relu')
    net = tflearn.conv_2d(net, 64, 4, strides=2, activation='relu')
    net = tflearn.fully_connected(net, 256, activation='relu')
    q_values = tflearn.fully_connected(net, num_actions)
    return inputs, q_values


# =============================
#   ATARI Environment Wrapper
# =============================
class AtariEnvironment(object):
    """
    Small wrapper for gym atari environments.
    Responsible for preprocessing screens and holding on to a screen buffer
    of size action_repeat from which environment state is constructed.
    """
    def __init__(self, gym_env, action_repeat):
        self.env = gym_env
        self.action_repeat = action_repeat

        # Agent available actions, such as LEFT, RIGHT, NOOP, etc...
        self.gym_actions = range(gym_env.action_space.n)
        # Screen buffer of size action_repeat to be able to build
        # state arrays of size [1, action_repeat, 84, 84]
        self.state_buffer = deque()

    def get_initial_state(self):
        """
        Resets the atari game, clears the state buffer.
        """
        # Clear the state buffer
        self.state_buffer = deque()

        x_t = self.env.reset()
        x_t = self.get_preprocessed_frame(x_t)
        s_t = np.stack([x_t for i in range(self.action_repeat)], axis=0)

        for i in range(self.action_repeat-1):
            self.state_buffer.append(x_t)
        return s_t

    def get_preprocessed_frame(self, observation):
        """
        0) Atari frames: 210 x 160
        1) Get image grayscale
        2) Rescale image 110 x 84
        3) Crop center 84 x 84 (you can crop top/bottom according to the game)
        """
        return resize(rgb2gray(observation), (110, 84))[13:110 - 13, :]

    def step(self, action_index):
        """
        Excecutes an action in the gym environment.
        Builds current state (concatenation of action_repeat-1 previous
        frames and current one). Pops oldest frame, adds current frame to
        the state buffer. Returns current state.
        """

        x_t1, r_t, terminal, info = self.env.step(self.gym_actions[action_index])
        x_t1 = self.get_preprocessed_frame(x_t1)

        previous_frames = np.array(self.state_buffer)
        s_t1 = np.empty((self.action_repeat, 84, 84))
        s_t1[:self.action_repeat-1, :] = previous_frames
        s_t1[self.action_repeat-1] = x_t1

        # Pop the oldest frame, add the current frame to the queue
        self.state_buffer.popleft()
        self.state_buffer.append(x_t1)

        return s_t1, r_t, terminal, info


# =============================
#   1-step Q-Learning
# =============================
def sample_final_epsilon():
    """
    Sample a final epsilon value to anneal towards from a distribution.
    These values are specified in section 5.1 of http://arxiv.org/pdf/1602.01783v1.pdf
    """
    final_epsilons = np.array([.1, .01, .5])
    probabilities = np.array([0.4, 0.3, 0.3])
    return np.random.choice(final_epsilons, 1, p=list(probabilities))[0]


def actor_learner_thread(thread_id, env, session, graph_ops, num_actions,
                         summary_ops, saver):
    """
    Actor-learner thread implementing asynchronous one-step Q-learning, as specified
    in algorithm 1 here: http://arxiv.org/pdf/1602.01783v1.pdf.
    """
    global TMAX, T

    # Unpack graph ops
    s = graph_ops["s"]
    q_values = graph_ops["q_values"]
    st = graph_ops["st"]
    target_q_values = graph_ops["target_q_values"]
    reset_target_network_params = graph_ops["reset_target_network_params"]
    a = graph_ops["a"]
    y = graph_ops["y"]
    grad_update = graph_ops["grad_update"]

    summary_placeholders, assign_ops, summary_op = summary_ops

    # Wrap env with AtariEnvironment helper class
    env = AtariEnvironment(gym_env=env,
                           action_repeat=action_repeat)

    # Initialize network gradients
    s_batch = []
    a_batch = []
    y_batch = []

    final_epsilon = sample_final_epsilon()
    initial_epsilon = 1.0
    epsilon = 1.0

    print("Thread " + str(thread_id) + " - Final epsilon: " + str(final_epsilon))

    time.sleep(3*thread_id)
    t = 0
    while T < TMAX:
        # Get initial game observation
        s_t = env.get_initial_state()
        terminal = False

        # Set up per-episode counters
        ep_reward = 0
        episode_ave_max_q = 0
        ep_t = 0

        while True:
            # Forward the deep q network, get Q(s,a) values
            readout_t = q_values.eval(session=session, feed_dict={s: [s_t]})

            # Choose next action based on e-greedy policy
            a_t = np.zeros([num_actions])
            if random.random() <= epsilon:
                action_index = random.randrange(num_actions)
            else:
                action_index = np.argmax(readout_t)
            a_t[action_index] = 1

            # Scale down epsilon
            if epsilon > final_epsilon:
                epsilon -= (initial_epsilon - final_epsilon) / anneal_epsilon_timesteps

            # Gym excecutes action in game environment on behalf of actor-learner
            s_t1, r_t, terminal, info = env.step(action_index)

            # Accumulate gradients
            readout_j1 = target_q_values.eval(session = session,
                                              feed_dict = {st : [s_t1]})
            clipped_r_t = np.clip(r_t, -1, 1)
            if terminal:
                y_batch.append(clipped_r_t)
            else:
                y_batch.append(clipped_r_t + gamma * np.max(readout_j1))

            a_batch.append(a_t)
            s_batch.append(s_t)

            # Update the state and counters
            s_t = s_t1
            T += 1
            t += 1

            ep_t += 1
            ep_reward += r_t
            episode_ave_max_q += np.max(readout_t)

            # Optionally update target network
            if T % I_target == 0:
                session.run(reset_target_network_params)

            # Optionally update online network
            if t % I_AsyncUpdate == 0 or terminal:
                if s_batch:
                    session.run(grad_update, feed_dict={y: y_batch,
                                                        a: a_batch,
                                                        s: s_batch})
                # Clear gradients
                s_batch = []
                a_batch = []
                y_batch = []

            # Save model progress
            if t % checkpoint_interval == 0:
                saver.save(session, "qlearning.ckpt", global_step=t)

            # Print end of episode stats
            if terminal:
                stats = [ep_reward, episode_ave_max_q/float(ep_t), epsilon]
                for i in range(len(stats)):
                    session.run(assign_ops[i],
                                {summary_placeholders[i]: float(stats[i])})
                print("| Thread %.2i" % int(thread_id), "| Step", t,
                      "| Reward: %.2i" % int(ep_reward), " Qmax: %.4f" %
                      (episode_ave_max_q/float(ep_t)),
                      " Epsilon: %.5f" % epsilon, " Epsilon progress: %.6f" %
                      (t/float(anneal_epsilon_timesteps)))
                break


def build_graph(num_actions):
    # Create shared deep q network
    s, q_network = build_dqn(num_actions=num_actions,
                             action_repeat=action_repeat)
    network_params = tf.trainable_variables()
    q_values = q_network

    # Create shared target network
    st, target_q_network = build_dqn(num_actions=num_actions,
                                     action_repeat=action_repeat)
    target_network_params = tf.trainable_variables()[len(network_params):]
    target_q_values = target_q_network

    # Op for periodically updating target network with online network weights
    reset_target_network_params = \
        [target_network_params[i].assign(network_params[i])
         for i in range(len(target_network_params))]

    # Define cost and gradient update op
    a = tf.placeholder("float", [None, num_actions])
    y = tf.placeholder("float", [None])
    action_q_values = tf.reduce_sum(tf.multiply(q_values, a), reduction_indices=1)
    cost = tflearn.mean_square(action_q_values, y)
    optimizer = tf.train.RMSPropOptimizer(learning_rate)
    grad_update = optimizer.minimize(cost, var_list=network_params)

    graph_ops = {"s": s,
                 "q_values": q_values,
                 "st": st,
                 "target_q_values": target_q_values,
                 "reset_target_network_params": reset_target_network_params,
                 "a": a,
                 "y": y,
                 "grad_update": grad_update}

    return graph_ops


# Set up some episode summary ops to visualize on tensorboard.
def build_summaries():
    episode_reward = tf.Variable(0.)
    scalar_summary("Reward", episode_reward)
    episode_ave_max_q = tf.Variable(0.)
    scalar_summary("Qmax Value", episode_ave_max_q)
    logged_epsilon = tf.Variable(0.)
    scalar_summary("Epsilon", logged_epsilon)
    # Threads shouldn't modify the main graph, so we use placeholders
    # to assign the value of every summary (instead of using assign method
    # in every thread, that would keep creating new ops in the graph)
    summary_vars = [episode_reward, episode_ave_max_q, logged_epsilon]
    summary_placeholders = [tf.placeholder("float")
                            for i in range(len(summary_vars))]
    assign_ops = [summary_vars[i].assign(summary_placeholders[i])
                  for i in range(len(summary_vars))]
    summary_op = merge_all_summaries()
    return summary_placeholders, assign_ops, summary_op


def get_num_actions():
    """
    Returns the number of possible actions for the given atari game
    """
    # Figure out number of actions from gym env
    env = gym.make(game)
    num_actions = env.action_space.n
    return num_actions


def train(session, graph_ops, num_actions, saver):
    """
    Train a model.
    """

    # Set up game environments (one per thread)
    envs = [gym.make(game) for i in range(n_threads)]

    summary_ops = build_summaries()
    summary_op = summary_ops[-1]

    # Initialize variables
    session.run(tf.initialize_all_variables())
    writer = writer_summary(summary_dir + "/qlearning", session.graph)

    # Initialize target network weights
    session.run(graph_ops["reset_target_network_params"])

    # Start n_threads actor-learner training threads
    actor_learner_threads = \
        [threading.Thread(target=actor_learner_thread,
                          args=(thread_id, envs[thread_id], session,
                                graph_ops, num_actions, summary_ops, saver))
         for thread_id in range(n_threads)]
    for t in actor_learner_threads:
        t.start()
        time.sleep(0.01)

    # Show the agents training and write summary statistics
    last_summary_time = 0
    while True:
        if show_training:
            for env in envs:
                env.render()
        now = time.time()
        if now - last_summary_time > summary_interval:
            summary_str = session.run(summary_op)
            writer.add_summary(summary_str, float(T))
            last_summary_time = now
    for t in actor_learner_threads:
        t.join()


def evaluation(session, graph_ops, saver):
    """
    Evaluate a model.
    """
    saver.restore(session, test_model_path)
    print("Restored model weights from ", test_model_path)
    monitor_env = gym.make(game)
    monitor_env.monitor.start("qlearning/eval")

    # Unpack graph ops
    s = graph_ops["s"]
    q_values = graph_ops["q_values"]

    # Wrap env with AtariEnvironment helper class
    env = AtariEnvironment(gym_env=monitor_env,
                           action_repeat=action_repeat)

    for i_episode in xrange(num_eval_episodes):
        s_t = env.get_initial_state()
        ep_reward = 0
        terminal = False
        while not terminal:
            monitor_env.render()
            readout_t = q_values.eval(session=session, feed_dict={s : [s_t]})
            action_index = np.argmax(readout_t)
            s_t1, r_t, terminal, info = env.step(action_index)
            s_t = s_t1
            ep_reward += r_t
        print(ep_reward)
    monitor_env.monitor.close()


def main(_):
    with tf.Session() as session:
        num_actions = get_num_actions()
        graph_ops = build_graph(num_actions)
        saver = tf.train.Saver(max_to_keep=5)

        if testing:
            evaluation(session, graph_ops, saver)
        else:
            train(session, graph_ops, num_actions, saver)

if __name__ == "__main__":
    tf.app.run()
# Out:
# [2017-05-31 01:45:42,391] Making new env: Breakout-v0
# [2017-05-31 01:45:43,005] Making new env: Breakout-v0
# [2017-05-31 01:45:43,165] Making new env: Breakout-v0
# [2017-05-31 01:45:43,331] Making new env: Breakout-v0
# [2017-05-31 01:45:43,490] Making new env: Breakout-v0
# [2017-05-31 01:45:43,653] Making new env: Breakout-v0
# [2017-05-31 01:45:43,814] Making new env: Breakout-v0
# [2017-05-31 01:45:43,978] Making new env: Breakout-v0
# [2017-05-31 01:45:44,144] Making new env: Breakout-v0
# INFO:tensorflow:Summary name Qmax Value is illegal; using Qmax_Value instead.
# [2017-05-31 01:45:44,322] Summary name Qmax Value is illegal; using Qmax_Value instead.
# WARNING:tensorflow:From <ipython-input-1-bd4829fb277f>:385: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2017-05-31 01:45:44,339] From <ipython-input-1-bd4829fb277f>:385: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Thread 0 - Final epsilon: 0.1
# Thread 1 - Final epsilon: 0.5
# Thread 2 - Final epsilon: 0.5
# Thread 3 - Final epsilon: 0.1
# Thread 4 - Final epsilon: 0.01
# Thread 5 - Final epsilon: 0.5
# Thread 6 - Final epsilon: 0.1
# Thread 7 - Final epsilon: 0.01
# | Thread 00 | Step 248 | Reward: 01  Qmax: 0.0483  Epsilon: 0.99944  Epsilon progress: 0.000620
# | Thread 01 | Step 170 | Reward: 00  Qmax: 0.0475  Epsilon: 0.99979  Epsilon progress: 0.000425
# | Thread 00 | Step 421 | Reward: 00  Qmax: 0.0524  Epsilon: 0.99905  Epsilon progress: 0.001053
# | Thread 02 | Step 180 | Reward: 00  Qmax: 0.0581  Epsilon: 0.99978  Epsilon progress: 0.000450
# | Thread 03 | Step 244 | Reward: 01  Qmax: 0.0562  Epsilon: 0.99945  Epsilon progress: 0.000610
# | Thread 04 | Step 238 | Reward: 01  Qmax: 0.0538  Epsilon: 0.99941  Epsilon progress: 0.000595
# | Thread 02 | Step 446 | Reward: 02  Qmax: 0.0543  Epsilon: 0.99944  Epsilon progress: 0.001115
# | Thread 05 | Step 217 | Reward: 01  Qmax: 0.0550  Epsilon: 0.99973  Epsilon progress: 0.000543
# | Thread 00 | Step 808 | Reward: 04  Qmax: 0.0556  Epsilon: 0.99818  Epsilon progress: 0.002020
# | Thread 06 | Step 213 | Reward: 01  Qmax: 0.0547  Epsilon: 0.99952  Epsilon progress: 0.000532
# | Thread 01 | Step 660 | Reward: 06  Qmax: 0.0570  Epsilon: 0.99918  Epsilon progress: 0.001650
# | Thread 07 | Step 226 | Reward: 01  Qmax: 0.0546  Epsilon: 0.99944  Epsilon progress: 0.000565
# | Thread 03 | Step 505 | Reward: 01  Qmax: 0.0543  Epsilon: 0.99886  Epsilon progress: 0.001262
# | Thread 04 | Step 490 | Reward: 02  Qmax: 0.0548  Epsilon: 0.99879  Epsilon progress: 0.001225
# | Thread 02 | Step 683 | Reward: 01  Qmax: 0.0542  Epsilon: 0.99915  Epsilon progress: 0.001708
# | Thread 06 | Step 397 | Reward: 00  Qmax: 0.0544  Epsilon: 0.99911  Epsilon progress: 0.000992
# | Thread 00 | Step 1034 | Reward: 01  Qmax: 0.0544  Epsilon: 0.99767  Epsilon progress: 0.002585
# | Thread 03 | Step 676 | Reward: 00  Qmax: 0.0538  Epsilon: 0.99848  Epsilon progress: 0.001690
# | Thread 01 | Step 929 | Reward: 02  Qmax: 0.0541  Epsilon: 0.99884  Epsilon progress: 0.002322
# | Thread 07 | Step 456 | Reward: 01  Qmax: 0.0543  Epsilon: 0.99887  Epsilon progress: 0.001140
# | Thread 05 | Step 627 | Reward: 04  Qmax: 0.0533  Epsilon: 0.99922  Epsilon progress: 0.001568
# | Thread 03 | Step 849 | Reward: 00  Qmax: 0.0505  Epsilon: 0.99809  Epsilon progress: 0.002122
# | Thread 02 | Step 947 | Reward: 02  Qmax: 0.0519  Epsilon: 0.99882  Epsilon progress: 0.002367
# | Thread 04 | Step 796 | Reward: 02  Qmax: 0.0519  Epsilon: 0.99803  Epsilon progress: 0.001990
# | Thread 07 | Step 632 | Reward: 00  Qmax: 0.0502  Epsilon: 0.99844  Epsilon progress: 0.001580
# | Thread 06 | Step 738 | Reward: 03  Qmax: 0.0514  Epsilon: 0.99834  Epsilon progress: 0.001845
# | Thread 00 | Step 1360 | Reward: 02  Qmax: 0.0512  Epsilon: 0.99694  Epsilon progress: 0.003400
# | Thread 05 | Step 857 | Reward: 01  Qmax: 0.0517  Epsilon: 0.99893  Epsilon progress: 0.002142
# | Thread 02 | Step 1161 | Reward: 01  Qmax: 0.0525| Thread 01 | Step 1290  | Reward: 03 Epsilon: 0.99855  Qmax: 0.0518  Epsilon: 0.99839  Epsilon progress: 0.003225
#  Epsilon progress: 0.002903
# | Thread 04 | Step 1007 | Reward: 01  Qmax: 0.0530  Epsilon: 0.99751  Epsilon progress: 0.002518
# | Thread 03 | Step 1131 | Reward: 02  Qmax: 0.0518  Epsilon: 0.99746  Epsilon progress: 0.002828
# | Thread 06 | Step 912 | Reward: 00  Qmax: 0.0528  Epsilon: 0.99795  Epsilon progress: 0.002280
# | Thread 07 | Step 912 | Reward: 02  Qmax: 0.0519  Epsilon: 0.99774  Epsilon progress: 0.002280
# | Thread 05 | Step 1031 | Reward: 00  Qmax: 0.0506  Epsilon: 0.99871  Epsilon progress: 0.002577
# | Thread 02 | Step 1322 | Reward: 00  Qmax: 0.0507  Epsilon: 0.99835  Epsilon progress: 0.003305
# | Thread 00 | Step 1649 | Reward: 03  Qmax: 0.0516  Epsilon: 0.99629  Epsilon progress: 0.004123
# | Thread 01 | Step 1475 | Reward: 00  Qmax: 0.0502  Epsilon: 0.99816  Epsilon progress: 0.003687
# | Thread 03 | Step 1297 | Reward: 00  Qmax: 0.0501  Epsilon: 0.99708  Epsilon progress: 0.003243
# | Thread 06 | Step 1080 | Reward: 00  Qmax: 0.0499  Epsilon: 0.99757  Epsilon progress: 0.002700
# | Thread 04 | Step 1249 | Reward: 01  Qmax: 0.0497  Epsilon: 0.99691  Epsilon progress: 0.003122
# | Thread 05 | Step 1262 | Reward: 01  Qmax: 0.0503  Epsilon: 0.99842  Epsilon progress: 0.003155
# | Thread 07 | Step 1188 | Reward: 02  Qmax: 0.0502  Epsilon: 0.99706  Epsilon progress: 0.002970
# | Thread 06 | Step 1251 | Reward: 00  Qmax: 0.0510  Epsilon: 0.99719  Epsilon progress: 0.003128
# | Thread 02 | Step 1553 | Reward: 01  Qmax: 0.0502  Epsilon: 0.99806  Epsilon progress: 0.003883
# | Thread 00 | Step 1873 | Reward: 01  Qmax: 0.0503  Epsilon: 0.99579  Epsilon progress: 0.004683
# | Thread 04 | Step 1439 | Reward: 00  Qmax: 0.0521  Epsilon: 0.99644  Epsilon progress: 0.003598
# | Thread 01 | Step 1740 | Reward: 02  Qmax: 0.0513  Epsilon: 0.99783  Epsilon progress: 0.004350
# | Thread 03 | Step 1613 | Reward: 02  Qmax: 0.0522  Epsilon: 0.99637  Epsilon progress: 0.004032
# | Thread 07 | Step 1369 | Reward: 00  Qmax: 0.0536  Epsilon: 0.99661  Epsilon progress: 0.003423
# | Thread 06 | Step 1472 | Reward: 01  Qmax: 0.0537  Epsilon: 0.99669  Epsilon progress: 0.003680
# | Thread 03 | Step 1824 | Reward: 01  Qmax: 0.0537  Epsilon: 0.99590  Epsilon progress: 0.004560
# | Thread 01 | Step 2011 | Reward: 02  Qmax: 0.0538  Epsilon: 0.99749  Epsilon progress: 0.005027
# | Thread 07 | Step 1591 | Reward: 01  Qmax: 0.0541  Epsilon: 0.99606  Epsilon progress: 0.003978
# | Thread 00 | Step 2242 | Reward: 03  Qmax: 0.0540  Epsilon: 0.99496  Epsilon progress: 0.005605
# | Thread 04 | Step 1795 | Reward: 04  Qmax: 0.0537  Epsilon: 0.99556  Epsilon progress: 0.004488
# | Thread 02 | Step 1972 | Reward: 04  Qmax: 0.0538  Epsilon: 0.99754  Epsilon progress: 0.004930
# | Thread 05 | Step 1760 | Reward: 06  Qmax: 0.0534  Epsilon: 0.99780  Epsilon progress: 0.004400
# | Thread 06 | Step 1748 | Reward: 02  Qmax: 0.0534  Epsilon: 0.99607  Epsilon progress: 0.004370
# | Thread 01 | Step 2186 | Reward: 00  Qmax: 0.0531  Epsilon: 0.99727  Epsilon progress: 0.005465
# | Thread 07 | Step 1758 | Reward: 00  Qmax: 0.0525  Epsilon: 0.99565  Epsilon progress: 0.004395
# | Thread 03 | Step 2043 | Reward: 01  Qmax: 0.0527  Epsilon: 0.99540  Epsilon progress: 0.005108
# | Thread 04 | Step 1976 | Reward: 00  Qmax: 0.0521  Epsilon: 0.99511  Epsilon progress: 0.004940
# | Thread 05 | Step 1920 | Reward: 00  Qmax: 0.0520  Epsilon: 0.99760  Epsilon progress: 0.004800
# | Thread 06 | Step 1917 | Reward: 00  Qmax: 0.0503  Epsilon: 0.99569  Epsilon progress: 0.004792
# | Thread 01 | Step 2404 | Reward: 01  Qmax: 0.0521  Epsilon: 0.99700  Epsilon progress: 0.006010
# | Thread 02 | Step 2288 | Reward: 03  Qmax: 0.0524  Epsilon: 0.99714  Epsilon progress: 0.005720
# | Thread 07 | Step 1985 | Reward: 01  Qmax: 0.0518  Epsilon: 0.99509  Epsilon progress: 0.004962
# | Thread 03 | Step 2292 | Reward: 01  Qmax: 0.0520  Epsilon: 0.99484  Epsilon progress: 0.005730
# | Thread 00 | Step 2725 | Reward: 05  Qmax: 0.0525  Epsilon: 0.99387  Epsilon progress: 0.006812
# | Thread 02 | Step 2468 | Reward: 00  Qmax: 0.0528  Epsilon: 0.99692  Epsilon progress: 0.006170
# | Thread 05 | Step 2226 | Reward: 02  Qmax: 0.0531  Epsilon: 0.99722  Epsilon progress: 0.005565
# | Thread 01 | Step 2639 | Reward: 01  Qmax: 0.0530  Epsilon: 0.99670  Epsilon progress: 0.006598
# | Thread 06 | Step 2208 | Reward: 02  Qmax: 0.0540  Epsilon: 0.99503  Epsilon progress: 0.005520
# | Thread 04 | Step 2398 | Reward: 04  Qmax: 0.0526  Epsilon: 0.99406  Epsilon progress: 0.005995
# | Thread 03 | Step 2521 | Reward: 01  Qmax: 0.0531  Epsilon: 0.99433  Epsilon progress: 0.006302
# | Thread 02 | Step 2648 | Reward: 00  Qmax: 0.0517  Epsilon: 0.99669  Epsilon progress: 0.006620
# | Thread 00 | Step 2965 | Reward: 01  Qmax: 0.0520  Epsilon: 0.99333  Epsilon progress: 0.007412
# | Thread 01 | Step 2811 | Reward: 00  Qmax: 0.0516  Epsilon: 0.99649  Epsilon progress: 0.007027
# | Thread 07 | Step 2388 | Reward: 04  Qmax: 0.0527  Epsilon: 0.99409  Epsilon progress: 0.005970
# | Thread 05 | Step 2493 | Reward: 02  Qmax: 0.0517  Epsilon: 0.99688  Epsilon progress: 0.006233
# | Thread 06 | Step 2433 | Reward: 01  Qmax: 0.0517  Epsilon: 0.99453  Epsilon progress: 0.006083
# | Thread 03 | Step 2716 | Reward: 00  Qmax: 0.0511  Epsilon: 0.99389  Epsilon progress: 0.006790
# | Thread 04 | Step 2608 | Reward: 01  Qmax: 0.0514  Epsilon: 0.99355  Epsilon progress: 0.006520
# | Thread 02 | Step 2827 | Reward: 00  Qmax: 0.0510  Epsilon: 0.99647  Epsilon progress: 0.007067
# | Thread 06 | Step 2606 | Reward: 00  Qmax: 0.0506  Epsilon: 0.99414  Epsilon progress: 0.006515
# | Thread 04 | Step 2776 | Reward: 00  Qmax: 0.0516  Epsilon: 0.99313  Epsilon progress: 0.006940
# | Thread 05 | Step 2768 | Reward: 02  Qmax: 0.0512  Epsilon: 0.99654  Epsilon progress: 0.006920
# | Thread 00 | Step 3306 | Reward: 03  Qmax: 0.0513  Epsilon: 0.99256  Epsilon progress: 0.008265
# | Thread 07 | Step 2688 | Reward: 02  Qmax: 0.0512  Epsilon: 0.99335  Epsilon progress: 0.006720
# | Thread 03 | Step 2993 | Reward: 02  Qmax: 0.0512  Epsilon: 0.99327  Epsilon progress: 0.007482
# | Thread 04 | Step 2959 | Reward: 00  Qmax: 0.0513  Epsilon: 0.99268  Epsilon progress: 0.007398
# | Thread 00 | Step 3491 | Reward: 00  Qmax: 0.0516  Epsilon: 0.99215  Epsilon progress: 0.008727
# | Thread 01 | Step 3344 | Reward: 06  Qmax: 0.0514  Epsilon: 0.99582  Epsilon progress: 0.008360
# | Thread 02 | Step 3229 | Reward: 04  Qmax: 0.0514  Epsilon: 0.99596  Epsilon progress: 0.008072
# | Thread 05 | Step 3017 | Reward: 01  Qmax: 0.0517  Epsilon: 0.99623  Epsilon progress: 0.007542
# | Thread 04 | Step 3128 | Reward: 00  Qmax: 0.0528  Epsilon: 0.99226  Epsilon progress: 0.007820
# | Thread 07 | Step 2972 | Reward: 02  Qmax: 0.0519  Epsilon: 0.99264  Epsilon progress: 0.007430
# | Thread 03 | Step 3246 | Reward: 02  Qmax: 0.0524  Epsilon: 0.99270  Epsilon progress: 0.008115
# | Thread 06 | Step 3039 | Reward: 04  Qmax: 0.0521  Epsilon: 0.99316  Epsilon progress: 0.007598
# | Thread 03 | Step 3420 | Reward: 00  Qmax: 0.0512  Epsilon: 0.99231  Epsilon progress: 0.008550
# | Thread 00 | Step 3795 | Reward: 02  Qmax: 0.0518  Epsilon: 0.99146  Epsilon progress: 0.009487
# | Thread 01 | Step 3645 | Reward: 02  Qmax: 0.0520  Epsilon: 0.99544  Epsilon progress: 0.009113
# | Thread 07 | Step 3193 | Reward: 01  Qmax: 0.0521  Epsilon: 0.99210  Epsilon progress: 0.007983
# | Thread 04 | Step 3364 | Reward: 01  Qmax: 0.0520  Epsilon: 0.99167  Epsilon progress: 0.008410
# | Thread 02 | Step 3560 | Reward: 03  Qmax: 0.0520  Epsilon: 0.99555  Epsilon progress: 0.008900
# | Thread 05 | Step 3331 | Reward: 02  Qmax: 0.0513  Epsilon: 0.99584  Epsilon progress: 0.008327
# | Thread 06 | Step 3388 | Reward: 03  Qmax: 0.0515  Epsilon: 0.99238  Epsilon progress: 0.008470
# | Thread 00 | Step 3981 | Reward: 00  Qmax: 0.0527  Epsilon: 0.99104  Epsilon progress: 0.009952
# | Thread 07 | Step 3438 | Reward: 02  Qmax: 0.0518  Epsilon: 0.99149  Epsilon progress: 0.008595
# | Thread 02 | Step 3781 | Reward: 01  Qmax: 0.0532  Epsilon: 0.99527  Epsilon progress: 0.009453
# | Thread 03 | Step 3761 | Reward: 03  Qmax: 0.0523  Epsilon: 0.99154  Epsilon progress: 0.009402
# | Thread 01 | Step 3989 | Reward: 03  Qmax: 0.0519  Epsilon: 0.99501  Epsilon progress: 0.009973
# | Thread 06 | Step 3567 | Reward: 00  Qmax: 0.0517  Epsilon: 0.99197  Epsilon progress: 0.008918
# | Thread 00 | Step 4155 | Reward: 00  Qmax: 0.0513  Epsilon: 0.99065  Epsilon progress: 0.010387
# | Thread 05 | Step 3639 | Reward: 02  Qmax: 0.0517  Epsilon: 0.99545  Epsilon progress: 0.009097
# | Thread 04 | Step 3780 | Reward: 04  Qmax: 0.0512  Epsilon: 0.99064  Epsilon progress: 0.009450
# | Thread 02 | Step 3948 | Reward: 00  Qmax: 0.0496  Epsilon: 0.99507  Epsilon progress: 0.009870
# | Thread 07 | Step 3637 | Reward: 00  Qmax: 0.0503  Epsilon: 0.99100  Epsilon progress: 0.009092
# | Thread 03 | Step 3941 | Reward: 00  Qmax: 0.0496  Epsilon: 0.99113  Epsilon progress: 0.009853
# | Thread 06 | Step 3783 | Reward: 01  Qmax: 0.0496  Epsilon: 0.99149  Epsilon progress: 0.009458
# | Thread 00 | Step 4389 | Reward: 01  Qmax: 0.0498  Epsilon: 0.99012  Epsilon progress: 0.010972
# | Thread 01 | Step 4218 | Reward: 01  Qmax: 0.0497  Epsilon: 0.99473  Epsilon progress: 0.010545
# | Thread 07 | Step 3816 | Reward: 00  Qmax: 0.0495  Epsilon: 0.99056  Epsilon progress: 0.009540
# | Thread 03 | Step 4098 | Reward: 00  Qmax: 0.0489  Epsilon: 0.99078  Epsilon progress: 0.010245
# | Thread 05 | Step 3925 | Reward: 02  Qmax: 0.0498  Epsilon: 0.99509  Epsilon progress: 0.009813
# | Thread 02 | Step 4194 | Reward: 01  Qmax: 0.0495  Epsilon: 0.99476  Epsilon progress: 0.010485
# | Thread 04 | Step 4052 | Reward: 02  Qmax: 0.0496  Epsilon: 0.98997  Epsilon progress: 0.010130
# | Thread 06 | Step 3955 | Reward: 00  Qmax: 0.0500  Epsilon: 0.99110  Epsilon progress: 0.009888
# | Thread 07 | Step 3991 | Reward: 00  Qmax: 0.0504  Epsilon: 0.99012  Epsilon progress: 0.009978
# | Thread 03 | Step 4268 | Reward: 00  Qmax: 0.0507  Epsilon: 0.99040  Epsilon progress: 0.010670
# | Thread 00 | Step 4636 | Reward: 01  Qmax: 0.0502  Epsilon: 0.98957  Epsilon progress: 0.011590
# | Thread 01 | Step 4512 | Reward: 02  Qmax: 0.0500  Epsilon: 0.99436  Epsilon progress: 0.011280
# | Thread 06 | Step 4143 | Reward: 00  Qmax: 0.0493  Epsilon: 0.99068  Epsilon progress: 0.010358
# | Thread 02 | Step 4432 | Reward: 01  Qmax: 0.0499  Epsilon: 0.99446  Epsilon progress: 0.011080
# | Thread 04 | Step 4278 | Reward: 01  Qmax: 0.0495  Epsilon: 0.98941  Epsilon progress: 0.010695
# | Thread 00 | Step 4807 | Reward: 00  Qmax: 0.0492  Epsilon: 0.98918  Epsilon progress: 0.012018
# | Thread 03 | Step 4442 | Reward: 00  Qmax: 0.0494  Epsilon: 0.99001  Epsilon progress: 0.011105
# | Thread 07 | Step 4235 | Reward: 01  Qmax: 0.0494  Epsilon: 0.98952  Epsilon progress: 0.010587
# | Thread 01 | Step 4681 | Reward: 00  Qmax: 0.0495  Epsilon: 0.99415  Epsilon progress: 0.011702
# | Thread 05 | Step 4306 | Reward: 03  Qmax: 0.0501  Epsilon: 0.99462  Epsilon progress: 0.010765
# | Thread 03 | Step 4629 | Reward: 00  Qmax: 0.0504  Epsilon: 0.98958  Epsilon progress: 0.011572
# | Thread 04 | Step 4564 | Reward: 02  Qmax: 0.0504  Epsilon: 0.98870  Epsilon progress: 0.011410
# | Thread 05 | Step 4493 | Reward: 00  Qmax: 0.0502  Epsilon: 0.99438  Epsilon progress: 0.011232
# | Thread 07 | Step 4476 | Reward: 01  Qmax: 0.0506  Epsilon: 0.98892  Epsilon progress: 0.011190
# | Thread 00 | Step 5110 | Reward: 02  Qmax: 0.0505  Epsilon: 0.98850  Epsilon progress: 0.012775
# | Thread 02 | Step 4820 | Reward: 04  Qmax: 0.0502  Epsilon: 0.99398  Epsilon progress: 0.012050
# | Thread 06 | Step 4526 | Reward: 04  Qmax: 0.0501  Epsilon: 0.98982  Epsilon progress: 0.011315
# | Thread 01 | Step 4957 | Reward: 02  Qmax: 0.0500  Epsilon: 0.99380  Epsilon progress: 0.012393
# | Thread 05 | Step 4661 | Reward: 00  Qmax: 0.0511  Epsilon: 0.99417  Epsilon progress: 0.011652
# | Thread 04 | Step 4754 | Reward: 00  Qmax: 0.0510  Epsilon: 0.98823  Epsilon progress: 0.011885
# | Thread 03 | Step 4870 | Reward: 01  Qmax: 0.0506  Epsilon: 0.98904  Epsilon progress: 0.012175
# | Thread 02 | Step 5002 | Reward: 00  Qmax: 0.0510  Epsilon: 0.99375  Epsilon progress: 0.012505
# | Thread 06 | Step 4774 | Reward: 01  Qmax: 0.0508  Epsilon: 0.98926  Epsilon progress: 0.011935
# | Thread 01 | Step 5197 | Reward: 01  Qmax: 0.0507  Epsilon: 0.99350  Epsilon progress: 0.012993
# | Thread 03 | Step 5050 | Reward: 00  Qmax: 0.0492  Epsilon: 0.98864  Epsilon progress: 0.012625
# | Thread 07 | Step 4814 | Reward: 03  Qmax: 0.0499  Epsilon: 0.98809  Epsilon progress: 0.012035
# | Thread 05 | Step 4878 | Reward: 01  Qmax: 0.0490  Epsilon: 0.99390  Epsilon progress: 0.012195
# | Thread 04 | Step 4964 | Reward: 01  Qmax: 0.0490  Epsilon: 0.98771  Epsilon progress: 0.012410
# | Thread 02 | Step 5173 | Reward: 00  Qmax: 0.0480  Epsilon: 0.99353  Epsilon progress: 0.012932
# | Thread 00 | Step 5546 | Reward: 04  Qmax: 0.0495  Epsilon: 0.98752  Epsilon progress: 0.013865
# | Thread 05 | Step 5061 | Reward: 00  Qmax: 0.0494  Epsilon: 0.99367  Epsilon progress: 0.012653
# | Thread 04 | Step 5178 | Reward: 01  Qmax: 0.0495  Epsilon: 0.98718  Epsilon progress: 0.012945
# | Thread 07 | Step 5046 | Reward: 01  Qmax: 0.0496  Epsilon: 0.98751  Epsilon progress: 0.012615
# | Thread 03 | Step 5318 | Reward: 02  Qmax: 0.0497  Epsilon: 0.98803  Epsilon progress: 0.013295
# | Thread 01 | Step 5549 | Reward: 03  Qmax: 0.0496  Epsilon: 0.99306  Epsilon progress: 0.013872
# | Thread 00 | Step 5781 | Reward: 01  Qmax: 0.0510  Epsilon: 0.98699  Epsilon progress: 0.014453
# | Thread 06 | Step 5154 | Reward: 04  Qmax: 0.0498  Epsilon: 0.98840  Epsilon progress: 0.012885
# | Thread 02 | Step 5473 | Reward: 02  Qmax: 0.0508  Epsilon: 0.99316  Epsilon progress: 0.013683
# | Thread 05 | Step 5270 | Reward: 01  Qmax: 0.0506  Epsilon: 0.99341  Epsilon progress: 0.013175
# | Thread 03 | Step 5496 | Reward: 00  Qmax: 0.0500  Epsilon: 0.98763  Epsilon progress: 0.013740
# | Thread 06 | Step 5333 | Reward: 00  Qmax: 0.0497  Epsilon: 0.98800  Epsilon progress: 0.013333
# | Thread 04 | Step 5479 | Reward: 02  Qmax: 0.0505  Epsilon: 0.98644  Epsilon progress: 0.013697
# | Thread 01 | Step 5774 | Reward: 01  Qmax: 0.0499  Epsilon: 0.99278  Epsilon progress: 0.014435
# | Thread 07 | Step 5355 | Reward: 02  Qmax: 0.0501  Epsilon: 0.98675  Epsilon progress: 0.013388
# | Thread 03 | Step 5665 | Reward: 00  Qmax: 0.0494  Epsilon: 0.98725  Epsilon progress: 0.014162
# | Thread 00 | Step 6054 | Reward: 02  Qmax: 0.0491  Epsilon: 0.98638  Epsilon progress: 0.015135
# | Thread 02 | Step 5803 | Reward: 03  Qmax: 0.0490  Epsilon: 0.99275  Epsilon progress: 0.014507
# | Thread 05 | Step 5536 | Reward: 02  Qmax: 0.0493  Epsilon: 0.99308  Epsilon progress: 0.013840
# | Thread 06 | Step 5502 | Reward: 00  Qmax: 0.0484  Epsilon: 0.98762  Epsilon progress: 0.013755
# | Thread 01 | Step 5941 | Reward: 00  Qmax: 0.0484  Epsilon: 0.99257  Epsilon progress: 0.014852
# | Thread 04 | Step 5659 | Reward: 00  Qmax: 0.0483  Epsilon: 0.98599  Epsilon progress: 0.014148
# | Thread 00 | Step 6235 | Reward: 00  Qmax: 0.0496  Epsilon: 0.98597  Epsilon progress: 0.015588
# | Thread 03 | Step 5939 | Reward: 02  Qmax: 0.0505  Epsilon: 0.98664  Epsilon progress: 0.014847
# | Thread 07 | Step 5678 | Reward: 02  Qmax: 0.0503  Epsilon: 0.98595  Epsilon progress: 0.014195
# | Thread 06 | Step 5701 | Reward: 01  Qmax: 0.0515  Epsilon: 0.98717  Epsilon progress: 0.014252
# | Thread 02 | Step 6081 | Reward: 02  Qmax: 0.0511  Epsilon: 0.99240  Epsilon progress: 0.015203
# | Thread 04 | Step 5941 | Reward: 02  Qmax: 0.0515  Epsilon: 0.98530  Epsilon progress: 0.014852
# | Thread 01 | Step 6226 | Reward: 02  Qmax: 0.0512  Epsilon: 0.99222  Epsilon progress: 0.015565
# | Thread 05 | Step 5895 | Reward: 03  Qmax: 0.0508  Epsilon: 0.99263  Epsilon progress: 0.014738
# | Thread 00 | Step 6483 | Reward: 01  Qmax: 0.0509  Epsilon: 0.98541  Epsilon progress: 0.016207
# | Thread 06 | Step 5895 | Reward: 00  Qmax: 0.0498  Epsilon: 0.98674  Epsilon progress: 0.014738
# | Thread 03 | Step 6172 | Reward: 01  Qmax: 0.0493  Epsilon: 0.98611  Epsilon progress: 0.015430
# | Thread 01 | Step 6417 | Reward: 00  Qmax: 0.0492  Epsilon: 0.99198  Epsilon progress: 0.016043
# | Thread 04 | Step 6125 | Reward: 00  Qmax: 0.0495  Epsilon: 0.98484  Epsilon progress: 0.015312
# | Thread 02 | Step 6314 | Reward: 01  Qmax: 0.0495  Epsilon: 0.99211  Epsilon progress: 0.015785
# | Thread 05 | Step 6061 | Reward: 00  Qmax: 0.0499  Epsilon: 0.99242  Epsilon progress: 0.015152
# | Thread 07 | Step 6019 | Reward: 03  Qmax: 0.0499  Epsilon: 0.98510  Epsilon progress: 0.015048
# | Thread 03 | Step 6366 | Reward: 00  Qmax: 0.0493  Epsilon: 0.98568  Epsilon progress: 0.015915
# | Thread 04 | Step 6294 | Reward: 00  Qmax: 0.0490  Epsilon: 0.98442  Epsilon progress: 0.015735
# | Thread 06 | Step 6182 | Reward: 02  Qmax: 0.0494  Epsilon: 0.98609  Epsilon progress: 0.015455
# | Thread 07 | Step 6195 | Reward: 00  Qmax: 0.0484  Epsilon: 0.98467  Epsilon progress: 0.015487
# | Thread 00 | Step 6888 | Reward: 04  Qmax: 0.0495  Epsilon: 0.98450  Epsilon progress: 0.017220
# | Thread 01 | Step 6742 | Reward: 03  Qmax: 0.0494  Epsilon: 0.99157  Epsilon progress: 0.016855
# | Thread 03 | Step 6588 | Reward: 01  Qmax: 0.0506  Epsilon: 0.98518  Epsilon progress: 0.016470
# | Thread 06 | Step 6348 | Reward: 00  Qmax: 0.0505  Epsilon: 0.98572  Epsilon progress: 0.015870
# | Thread 02 | Step 6677 | Reward: 03  Qmax: 0.0497  Epsilon: 0.99165  Epsilon progress: 0.016692
# | Thread 07 | Step 6369 | Reward: 00  Qmax: 0.0504  Epsilon: 0.98424  Epsilon progress: 0.015922
# | Thread 05 | Step 6438 | Reward: 03  Qmax: 0.0494  Epsilon: 0.99195  Epsilon progress: 0.016095
# | Thread 04 | Step 6540 | Reward: 01  Qmax: 0.0498  Epsilon: 0.98381  Epsilon progress: 0.016350
# | Thread 00 | Step 7121 | Reward: 01  Qmax: 0.0503  Epsilon: 0.98398  Epsilon progress: 0.017802
# | Thread 01 | Step 6958 | Reward: 01  Qmax: 0.0501  Epsilon: 0.99130  Epsilon progress: 0.017395
# | Thread 06 | Step 6571 | Reward: 01  Qmax: 0.0498  Epsilon: 0.98522  Epsilon progress: 0.016428
# | Thread 02 | Step 6900 | Reward: 01  Qmax: 0.0499  Epsilon: 0.99138  Epsilon progress: 0.017250
# | Thread 07 | Step 6582 | Reward: 01  Qmax: 0.0501  Epsilon: 0.98371  Epsilon progress: 0.016455
# | Thread 03 | Step 6857 | Reward: 02  Qmax: 0.0500  Epsilon: 0.98457  Epsilon progress: 0.017143
# | Thread 04 | Step 6805 | Reward: 02  Qmax: 0.0501  Epsilon: 0.98316  Epsilon progress: 0.017012
# | Thread 05 | Step 6736 | Reward: 02  Qmax: 0.0501  Epsilon: 0.99158  Epsilon progress: 0.016840
# | Thread 00 | Step 7325 | Reward: 01  Qmax: 0.0501  Epsilon: 0.98352  Epsilon progress: 0.018312
# | Thread 01 | Step 7141 | Reward: 00  Qmax: 0.0500  Epsilon: 0.99107  Epsilon progress: 0.017853
# | Thread 06 | Step 6737 | Reward: 00  Qmax: 0.0500  Epsilon: 0.98484  Epsilon progress: 0.016842
# | Thread 02 | Step 7084 | Reward: 00  Qmax: 0.0495  Epsilon: 0.99115  Epsilon progress: 0.017710
# | Thread 03 | Step 7089 | Reward: 01  Qmax: 0.0493  Epsilon: 0.98405  Epsilon progress: 0.017722
# | Thread 07 | Step 6852 | Reward: 02  Qmax: 0.0492  Epsilon: 0.98304  Epsilon progress: 0.017130
# | Thread 05 | Step 6918 | Reward: 00  Qmax: 0.0494  Epsilon: 0.99135  Epsilon progress: 0.017295
# | Thread 01 | Step 7315 | Reward: 00  Qmax: 0.0490  Epsilon: 0.99086  Epsilon progress: 0.018288
# | Thread 04 | Step 7069 | Reward: 01  Qmax: 0.0493  Epsilon: 0.98250  Epsilon progress: 0.017673
# | Thread 02 | Step 7265 | Reward: 00  Qmax: 0.0489  Epsilon: 0.99092  Epsilon progress: 0.018163
# | Thread 00 | Step 7564 | Reward: 02  Qmax: 0.0488  Epsilon: 0.98298  Epsilon progress: 0.018910
# | Thread 06 | Step 6972 | Reward: 01  Qmax: 0.0487  Epsilon: 0.98431  Epsilon progress: 0.017430
# | Thread 03 | Step 7263 | Reward: 00  Qmax: 0.0495  Epsilon: 0.98366  Epsilon progress: 0.018158
# | Thread 07 | Step 7090 | Reward: 01  Qmax: 0.0499  Epsilon: 0.98245  Epsilon progress: 0.017725
# | Thread 00 | Step 7747 | Reward: 00  Qmax: 0.0508  Epsilon: 0.98257  Epsilon progress: 0.019367
# | Thread 01 | Step 7586 | Reward: 02  Qmax: 0.0498  Epsilon: 0.99052  Epsilon progress: 0.018965
# | Thread 03 | Step 7432 | Reward: 00  Qmax: 0.0508  Epsilon: 0.98328  Epsilon progress: 0.018580
# | Thread 06 | Step 7188 | Reward: 01  Qmax: 0.0510  Epsilon: 0.98383  Epsilon progress: 0.017970
# | Thread 05 | Step 7240 | Reward: 02  Qmax: 0.0501  Epsilon: 0.99095  Epsilon progress: 0.018100
# | Thread 07 | Step 7262 | Reward: 00  Qmax: 0.0505  Epsilon: 0.98203  Epsilon progress: 0.018155
# | Thread 04 | Step 7425 | Reward: 03  Qmax: 0.0506  Epsilon: 0.98162  Epsilon progress: 0.018562
# | Thread 02 | Step 7636 | Reward: 04  Qmax: 0.0507  Epsilon: 0.99046  Epsilon progress: 0.019090
# | Thread 00 | Step 7935 | Reward: 00  Qmax: 0.0503  Epsilon: 0.98215  Epsilon progress: 0.019838
# | Thread 05 | Step 7414 | Reward: 00  Qmax: 0.0494  Epsilon: 0.99073  Epsilon progress: 0.018535
# | Thread 01 | Step 7830 | Reward: 01  Qmax: 0.0496  Epsilon: 0.99021  Epsilon progress: 0.019575
# | Thread 06 | Step 7412 | Reward: 01  Qmax: 0.0491  Epsilon: 0.98332  Epsilon progress: 0.018530
# | Thread 03 | Step 7729 | Reward: 02  Qmax: 0.0504  Epsilon: 0.98261  Epsilon progress: 0.019322
# | Thread 07 | Step 7511 | Reward: 02  Qmax: 0.0510  Epsilon: 0.98141  Epsilon progress: 0.018777
# | Thread 04 | Step 7671 | Reward: 01  Qmax: 0.0503  Epsilon: 0.98101  Epsilon progress: 0.019178
# | Thread 02 | Step 7874 | Reward: 01  Qmax: 0.0503  Epsilon: 0.99016  Epsilon progress: 0.019685
# | Thread 00 | Step 8251 | Reward: 02  Qmax: 0.0512  Epsilon: 0.98144  Epsilon progress: 0.020628
# | Thread 05 | Step 7710 | Reward: 02  Qmax: 0.0516  Epsilon: 0.99036  Epsilon progress: 0.019275
# | Thread 01 | Step 8133 | Reward: 02  Qmax: 0.0519  Epsilon: 0.98983  Epsilon progress: 0.020332
# | Thread 04 | Step 7837 | Reward: 00  Qmax: 0.0515  Epsilon: 0.98060  Epsilon progress: 0.019592
# | Thread 02 | Step 8051 | Reward: 00  Qmax: 0.0507  Epsilon: 0.98994  Epsilon progress: 0.020127
# | Thread 07 | Step 7755 | Reward: 01  Qmax: 0.0509  Epsilon: 0.98081  Epsilon progress: 0.019387
# | Thread 06 | Step 7778 | Reward: 03  Qmax: 0.0517  Epsilon: 0.98250  Epsilon progress: 0.019445
# | Thread 03 | Step 8055 | Reward: 02  Qmax: 0.0509  Epsilon: 0.98188  Epsilon progress: 0.020137
# | Thread 00 | Step 8419 | Reward: 00  Qmax: 0.0497  Epsilon: 0.98106  Epsilon progress: 0.021048
# | Thread 05 | Step 7884 | Reward: 00  Qmax: 0.0493  Epsilon: 0.99015  Epsilon progress: 0.019710
# | Thread 04 | Step 8107 | Reward: 02  Qmax: 0.0519  Epsilon: 0.97994  Epsilon progress: 0.020268
# | Thread 01 | Step 8436 | Reward: 03  Qmax: 0.0516  Epsilon: 0.98946  Epsilon progress: 0.021090
# | Thread 07 | Step 8042 | Reward: 02  Qmax: 0.0523  Epsilon: 0.98010  Epsilon progress: 0.020105
# | Thread 00 | Step 8671 | Reward: 02  Qmax: 0.0537  Epsilon: 0.98049  Epsilon progress: 0.021677
# | Thread 06 | Step 8078 | Reward: 03  Qmax: 0.0532  Epsilon: 0.98182  Epsilon progress: 0.020195
# | Thread 03 | Step 8394 | Reward: 04  Qmax: 0.0525  Epsilon: 0.98111  Epsilon progress: 0.020985
# | Thread 02 | Step 8444 | Reward: 04  Qmax: 0.0520  Epsilon: 0.98945  Epsilon progress: 0.021110
# | Thread 05 | Step 8187 | Reward: 02  Qmax: 0.0523  Epsilon: 0.98977  Epsilon progress: 0.020467
# | Thread 04 | Step 8293 | Reward: 00  Qmax: 0.0527  Epsilon: 0.97947  Epsilon progress: 0.020733
# | Thread 06 | Step 8245 | Reward: 00  Qmax: 0.0515  Epsilon: 0.98145  Epsilon progress: 0.020612
# | Thread 07 | Step 8249 | Reward: 01  Qmax: 0.0513  Epsilon: 0.97958  Epsilon progress: 0.020622
# | Thread 01 | Step 8717 | Reward: 02  Qmax: 0.0515  Epsilon: 0.98910  Epsilon progress: 0.021792
# | Thread 03 | Step 8567 | Reward: 00  Qmax: 0.0509  Epsilon: 0.98072  Epsilon progress: 0.021417
# | Thread 05 | Step 8368 | Reward: 00  Qmax: 0.0504  Epsilon: 0.98954  Epsilon progress: 0.020920
# | Thread 00 | Step 8943 | Reward: 02  Qmax: 0.0501  Epsilon: 0.97988  Epsilon progress: 0.022357
# | Thread 04 | Step 8517 | Reward: 01  Qmax: 0.0499  Epsilon: 0.97892  Epsilon progress: 0.021292
# | Thread 01 | Step 8902 | Reward: 00  Qmax: 0.0502  Epsilon: 0.98887  Epsilon progress: 0.022255
# | Thread 06 | Step 8550 | Reward: 02  Qmax: 0.0515  Epsilon: 0.98076  Epsilon progress: 0.021375
# | Thread 05 | Step 8595 | Reward: 01  Qmax: 0.0533  Epsilon: 0.98926  Epsilon progress: 0.021487
# | Thread 02 | Step 8877 | Reward: 05  Qmax: 0.0517  Epsilon: 0.98890  Epsilon progress: 0.022193
# | Thread 00 | Step 9178 | Reward: 01  Qmax: 0.0533  Epsilon: 0.97935  Epsilon progress: 0.022945
# | Thread 07 | Step 8573 | Reward: 03  Qmax: 0.0514  Epsilon: 0.97878  Epsilon progress: 0.021433
# | Thread 03 | Step 8912 | Reward: 03  Qmax: 0.0514  Epsilon: 0.97995  Epsilon progress: 0.022280
# | Thread 01 | Step 9087 | Reward: 00  Qmax: 0.0530  Epsilon: 0.98864  Epsilon progress: 0.022718
# | Thread 04 | Step 8813 | Reward: 02  Qmax: 0.0524  Epsilon: 0.97819  Epsilon progress: 0.022033
# | Thread 07 | Step 8746 | Reward: 00  Qmax: 0.0512  Epsilon: 0.97835  Epsilon progress: 0.021865
# | Thread 02 | Step 9085 | Reward: 01  Qmax: 0.0499  Epsilon: 0.98864  Epsilon progress: 0.022713
# | Thread 06 | Step 8831 | Reward: 02  Qmax: 0.0508  Epsilon: 0.98013  Epsilon progress: 0.022077
# | Thread 05 | Step 8873 | Reward: 02  Qmax: 0.0510  Epsilon: 0.98891  Epsilon progress: 0.022183
# | Thread 00 | Step 9468 | Reward: 03  Qmax: 0.0509  Epsilon: 0.97870  Epsilon progress: 0.023670
# | Thread 01 | Step 9318 | Reward: 01  Qmax: 0.0509  Epsilon: 0.98835  Epsilon progress: 0.023295
# | Thread 04 | Step 9047 | Reward: 01  Qmax: 0.0526  Epsilon: 0.97761  Epsilon progress: 0.022617
# | Thread 02 | Step 9260 | Reward: 00  Qmax: 0.0528  Epsilon: 0.98843  Epsilon progress: 0.023150
# | Thread 03 | Step 9226 | Reward: 02  Qmax: 0.0526  Epsilon: 0.97924  Epsilon progress: 0.023065
# | Thread 07 | Step 9043 | Reward: 02  Qmax: 0.0514  Epsilon: 0.97762  Epsilon progress: 0.022607
# | Thread 00 | Step 9674 | Reward: 01  Qmax: 0.0514  Epsilon: 0.97823  Epsilon progress: 0.024185
# | Thread 06 | Step 9067 | Reward: 01  Qmax: 0.0509  Epsilon: 0.97960  Epsilon progress: 0.022668
# | Thread 05 | Step 9135 | Reward: 01  Qmax: 0.0505  Epsilon: 0.98858  Epsilon progress: 0.022838
# | Thread 04 | Step 9211 | Reward: 00  Qmax: 0.0486  Epsilon: 0.97720  Epsilon progress: 0.023027
# | Thread 01 | Step 9530 | Reward: 01  Qmax: 0.0506  Epsilon: 0.98809  Epsilon progress: 0.023825
# | Thread 03 | Step 9443 | Reward: 01  Qmax: 0.0494  Epsilon: 0.97875  Epsilon progress: 0.023608
# | Thread 06 | Step 9247 | Reward: 00  Qmax: 0.0499  Epsilon: 0.97919  Epsilon progress: 0.023117
# | Thread 05 | Step 9311 | Reward: 00  Qmax: 0.0510  Epsilon: 0.98836  Epsilon progress: 0.023277
# | Thread 02 | Step 9590 | Reward: 04  Qmax: 0.0502  Epsilon: 0.98801  Epsilon progress: 0.023975
# | Thread 07 | Step 9308 | Reward: 01  Qmax: 0.0504  Epsilon: 0.97696  Epsilon progress: 0.023270
# | Thread 01 | Step 9759 | Reward: 01  Qmax: 0.0513  Epsilon: 0.98780  Epsilon progress: 0.024397
# | Thread 00 | Step 9965 | Reward: 02  Qmax: 0.0506  Epsilon: 0.97758  Epsilon progress: 0.024913
# | Thread 04 | Step 9518 | Reward: 03  Qmax: 0.0506  Epsilon: 0.97644  Epsilon progress: 0.023795
# | Thread 06 | Step 9423 | Reward: 00  Qmax: 0.0505  Epsilon: 0.97880  Epsilon progress: 0.023557
# | Thread 02 | Step 9762 | Reward: 00  Qmax: 0.0498  Epsilon: 0.98780  Epsilon progress: 0.024405
# | Thread 03 | Step 9717 | Reward: 02  Qmax: 0.0500  Epsilon: 0.97814  Epsilon progress: 0.024293
# | Thread 05 | Step 9518 | Reward: 00  Qmax: 0.0501  Epsilon: 0.98810  Epsilon progress: 0.023795
# | Thread 04 | Step 9696 | Reward: 00  Qmax: 0.0489  Epsilon: 0.97600  Epsilon progress: 0.024240
# | Thread 07 | Step 9606 | Reward: 02  Qmax: 0.0496  Epsilon: 0.97623  Epsilon progress: 0.024015
# | Thread 02 | Step 9934 | Reward: 00  Qmax: 0.0490  Epsilon: 0.98758  Epsilon progress: 0.024835
# | Thread 03 | Step 9894 | Reward: 00  Qmax: 0.0488  Epsilon: 0.97774  Epsilon progress: 0.024735
# | Thread 00 | Step 10254 | Reward: 02  Qmax: 0.0496  Epsilon: 0.97693  Epsilon progress: 0.025635
# | Thread 06 | Step 9659 | Reward: 01  Qmax: 0.0495  Epsilon: 0.97827  Epsilon progress: 0.024147
# | Thread 01 | Step 10084 | Reward: 03  Qmax: 0.0499  Epsilon: 0.98740  Epsilon progress: 0.025210
# | Thread 05 | Step 9728 | Reward: 01  Qmax: 0.0494  Epsilon: 0.98784  Epsilon progress: 0.024320
# | Thread 04 | Step 9873 | Reward: 00  Qmax: 0.0497  Epsilon: 0.97556  Epsilon progress: 0.024682
# | Thread 07 | Step 9795 | Reward: 00  Qmax: 0.0500  Epsilon: 0.97576  Epsilon progress: 0.024487
# | Thread 03 | Step 10074 | Reward: 00  Qmax: 0.0500  Epsilon: 0.97733  Epsilon progress: 0.025185
# | Thread 01 | Step 10258 | Reward: 00  Qmax: 0.0497  Epsilon: 0.98718  Epsilon progress: 0.025645
# | Thread 02 | Step 10207 | Reward: 02  Qmax: 0.0511  Epsilon: 0.98724  Epsilon progress: 0.025517
# | Thread 00 | Step 10545 | Reward: 02  Qmax: 0.0503  Epsilon: 0.97627  Epsilon progress: 0.026363
# | Thread 07 | Step 9967 | Reward: 00  Qmax: 0.0504  Epsilon: 0.97533  Epsilon progress: 0.024917
# | Thread 06 | Step 10019 | Reward: 04  Qmax: 0.0506  Epsilon: 0.97746  Epsilon progress: 0.025048
# | Thread 04 | Step 10159 | Reward: 02  Qmax: 0.0502  Epsilon: 0.97486  Epsilon progress: 0.025397
# | Thread 05 | Step 10085 | Reward: 04  Qmax: 0.0513  Epsilon: 0.98739  Epsilon progress: 0.025212
# | Thread 02 | Step 10414 | Reward: 01  Qmax: 0.0503  Epsilon: 0.98698  Epsilon progress: 0.026035
# | Thread 01 | Step 10541 | Reward: 02  Qmax: 0.0510  Epsilon: 0.98682  Epsilon progress: 0.026353
# | Thread 07 | Step 10140 | Reward: 00  Qmax: 0.0500  Epsilon: 0.97490  Epsilon progress: 0.025350
# | Thread 06 | Step 10196 | Reward: 00  Qmax: 0.0502  Epsilon: 0.97706  Epsilon progress: 0.025490
# | Thread 04 | Step 10378 | Reward: 01  Qmax: 0.0520  Epsilon: 0.97431  Epsilon progress: 0.025945
# | Thread 00 | Step 10884 | Reward: 03  Qmax: 0.0519  Epsilon: 0.97551  Epsilon progress: 0.027210
# | Thread 03 | Step 10608 | Reward: 06  Qmax: 0.0515  Epsilon: 0.97613  Epsilon progress: 0.026520
# | Thread 01 | Step 10823 | Reward: 02  Qmax: 0.0528  Epsilon: 0.98647  Epsilon progress: 0.027058
# | Thread 02 | Step 10750 | Reward: 03  Qmax: 0.0515  Epsilon: 0.98656  Epsilon progress: 0.026875
# | Thread 00 | Step 11058 | Reward: 00  Qmax: 0.0501  Epsilon: 0.97512  Epsilon progress: 0.027645
# | Thread 04 | Step 10553 | Reward: 00  Qmax: 0.0496  Epsilon: 0.97388  Epsilon progress: 0.026382
# | Thread 05 | Step 10484 | Reward: 04  Qmax: 0.0513  Epsilon: 0.98690  Epsilon progress: 0.026210
# | Thread 06 | Step 10513 | Reward: 02  Qmax: 0.0533  Epsilon: 0.97635  Epsilon progress: 0.026283
# | Thread 07 | Step 10539 | Reward: 07  Qmax: 0.0528  Epsilon: 0.97392  Epsilon progress: 0.026347
# | Thread 02 | Step 10928 | Reward: 00  Qmax: 0.0527  Epsilon: 0.98634  Epsilon progress: 0.027320
# | Thread 03 | Step 10904 | Reward: 02  Qmax: 0.0523  Epsilon: 0.97547  Epsilon progress: 0.027260
# | Thread 04 | Step 10738 | Reward: 00  Qmax: 0.0518  Epsilon: 0.97342  Epsilon progress: 0.026845
# | Thread 05 | Step 10741 | Reward: 01  Qmax: 0.0506  Epsilon: 0.98657  Epsilon progress: 0.026853
# | Thread 07 | Step 10717 | Reward: 00  Qmax: 0.0504  Epsilon: 0.97348  Epsilon progress: 0.026793
# | Thread 06 | Step 10719 | Reward: 01  Qmax: 0.0504  Epsilon: 0.97588  Epsilon progress: 0.026797
# | Thread 01 | Step 11200 | Reward: 04  Qmax: 0.0518  Epsilon: 0.98600  Epsilon progress: 0.028000
# | Thread 02 | Step 11099 | Reward: 00  Qmax: 0.0494  Epsilon: 0.98613  Epsilon progress: 0.027748
# | Thread 04 | Step 10968 | Reward: 01  Qmax: 0.0518  Epsilon: 0.97285  Epsilon progress: 0.027420
# | Thread 00 | Step 11507 | Reward: 04  Qmax: 0.0519  Epsilon: 0.97411  Epsilon progress: 0.028768
# | Thread 06 | Step 10933 | Reward: 01  Qmax: 0.0519  Epsilon: 0.97540  Epsilon progress: 0.027332
# | Thread 01 | Step 11382 | Reward: 00  Qmax: 0.0525  Epsilon: 0.98577  Epsilon progress: 0.028455
# | Thread 03 | Step 11247 | Reward: 03  Qmax: 0.0505  Epsilon: 0.97469  Epsilon progress: 0.028118
# | Thread 05 | Step 11088 | Reward: 03  Qmax: 0.0519  Epsilon: 0.98614  Epsilon progress: 0.027720
# | Thread 07 | Step 11080 | Reward: 03  Qmax: 0.0528  Epsilon: 0.97258  Epsilon progress: 0.027700
# | Thread 00 | Step 11745 | Reward: 01  Qmax: 0.0531  Epsilon: 0.97357  Epsilon progress: 0.029362
# | Thread 02 | Step 11433 | Reward: 03  Qmax: 0.0530  Epsilon: 0.98571  Epsilon progress: 0.028583
# | Thread 06 | Step 11141 | Reward: 01  Qmax: 0.0529  Epsilon: 0.97493  Epsilon progress: 0.027852
# | Thread 04 | Step 11348 | Reward: 03  Qmax: 0.0519  Epsilon: 0.97191  Epsilon progress: 0.028370
# | Thread 03 | Step 11544 | Reward: 02  Qmax: 0.0538  Epsilon: 0.97403  Epsilon progress: 0.028860
# | Thread 02 | Step 11607 | Reward: 00  Qmax: 0.0535  Epsilon: 0.98549  Epsilon progress: 0.029018
# | Thread 01 | Step 11782 | Reward: 04  Qmax: 0.0528  Epsilon: 0.98527  Epsilon progress: 0.029455
# | Thread 07 | Step 11350 | Reward: 02  Qmax: 0.0528  Epsilon: 0.97191  Epsilon progress: 0.028375
# | Thread 00 | Step 11981 | Reward: 01  Qmax: 0.0510  Epsilon: 0.97304  Epsilon progress: 0.029952
# | Thread 06 | Step 11367 | Reward: 01  Qmax: 0.0535  Epsilon: 0.97442  Epsilon progress: 0.028417
# | Thread 05 | Step 11426 | Reward: 03  Qmax: 0.0535  Epsilon: 0.98572  Epsilon progress: 0.028565
# | Thread 02 | Step 11775 | Reward: 00  Qmax: 0.0506  Epsilon: 0.98528  Epsilon progress: 0.029437
# | Thread 04 | Step 11567 | Reward: 01  Qmax: 0.0515  Epsilon: 0.97137  Epsilon progress: 0.028917
# | Thread 07 | Step 11516 | Reward: 00  Qmax: 0.0501  Epsilon: 0.97150  Epsilon progress: 0.028790
# | Thread 03 | Step 11832 | Reward: 02  Qmax: 0.0505  Epsilon: 0.97338  Epsilon progress: 0.029580
# | Thread 01 | Step 12043 | Reward: 02  Qmax: 0.0514  Epsilon: 0.98495  Epsilon progress: 0.030107
# | Thread 02 | Step 11949 | Reward: 00 | Thread 06 Qmax: 0.0512  Epsilon: 0.98506  Epsilon progress: 0.029872
#  | Step 11621 | Reward: 01  Qmax: 0.0516  Epsilon: 0.97385  Epsilon progress: 0.029052
# | Thread 00 | Step 12252 | Reward: 02  Qmax: 0.0506  Epsilon: 0.97243  Epsilon progress: 0.030630
# | Thread 04 | Step 11804 | Reward: 01  Qmax: 0.0501  Epsilon: 0.97079  Epsilon progress: 0.029510
# | Thread 05 | Step 11756 | Reward: 03  Qmax: 0.0494  Epsilon: 0.98531  Epsilon progress: 0.029390
# | Thread 03 | Step 12004 | Reward: 00  Qmax: 0.0505  Epsilon: 0.97299  Epsilon progress: 0.030010
# | Thread 01 | Step 12230 | Reward: 00  Qmax: 0.0484  Epsilon: 0.98471  Epsilon progress: 0.030575
# | Thread 02 | Step 12120 | Reward: 00  Qmax: 0.0486  Epsilon: 0.98485  Epsilon progress: 0.030300
# | Thread 00 | Step 12441 | Reward: 00  Qmax: 0.0487  Epsilon: 0.97201  Epsilon progress: 0.031103
# | Thread 06 | Step 11845 | Reward: 01  Qmax: 0.0484  Epsilon: 0.97335  Epsilon progress: 0.029612
# | Thread 07 | Step 11908 | Reward: 04  Qmax: 0.0505  Epsilon: 0.97053  Epsilon progress: 0.029770
# | Thread 04 | Step 12027 | Reward: 01  Qmax: 0.0524  Epsilon: 0.97023  Epsilon progress: 0.030068
# | Thread 01 | Step 12469 | Reward: 01  Qmax: 0.0552  Epsilon: 0.98441  Epsilon progress: 0.031172
# | Thread 05 | Step 12064 | Reward: 02  Qmax: 0.0533  Epsilon: 0.98492  Epsilon progress: 0.030160
# | Thread 03 | Step 12334 | Reward: 03  Qmax: 0.0513  Epsilon: 0.97225  Epsilon progress: 0.030835
# | Thread 06 | Step 12080 | Reward: 01  Qmax: 0.0539  Epsilon: 0.97282  Epsilon progress: 0.030200
# | Thread 02 | Step 12424 | Reward: 02  Qmax: 0.0551  Epsilon: 0.98447  Epsilon progress: 0.031060
# | Thread 00 | Step 12764 | Reward: 02  Qmax: 0.0560  Epsilon: 0.97128  Epsilon progress: 0.031910
# | Thread 07 | Step 12213 | Reward: 02  Qmax: 0.0546  Epsilon: 0.96977  Epsilon progress: 0.030533
# | Thread 01 | Step 12688 | Reward: 01  Qmax: 0.0542  Epsilon: 0.98414  Epsilon progress: 0.031720
# | Thread 04 | Step 12366 | Reward: 03  Qmax: 0.0529  Epsilon: 0.96939  Epsilon progress: 0.030915
# | Thread 06 | Step 12283 | Reward: 01  Qmax: 0.0531  Epsilon: 0.97236  Epsilon progress: 0.030707
# | Thread 05 | Step 12333 | Reward: 02  Qmax: 0.0535  Epsilon: 0.98458  Epsilon progress: 0.030832
# | Thread 02 | Step 12631 | Reward: 01  Qmax: 0.0516  Epsilon: 0.98421  Epsilon progress: 0.031578
# | Thread 00 | Step 12943 | Reward: 00  Qmax: 0.0526  Epsilon: 0.97088  Epsilon progress: 0.032357
# | Thread 01 | Step 12854 | Reward: 00  Qmax: 0.0512  Epsilon: 0.98393  Epsilon progress: 0.032135
# | Thread 07 | Step 12450 | Reward: 01  Qmax: 0.0521  Epsilon: 0.96919  Epsilon progress: 0.031125
# | Thread 03 | Step 12766 | Reward: 05  Qmax: 0.0533  Epsilon: 0.97128  Epsilon progress: 0.031915
# | Thread 05 | Step 12532 | Reward: 01  Qmax: 0.0522  Epsilon: 0.98434  Epsilon progress: 0.031330
# | Thread 00 | Step 13123 | Reward: 00  Qmax: 0.0525  Epsilon: 0.97047  Epsilon progress: 0.032808
# | Thread 02 | Step 12860 | Reward: 01  Qmax: 0.0525  Epsilon: 0.98393  Epsilon progress: 0.032150
# | Thread 04 | Step 12644 | Reward: 02  Qmax: 0.0525  Epsilon: 0.96871  Epsilon progress: 0.031610
# | Thread 06 | Step 12600 | Reward: 03  Qmax: 0.0519  Epsilon: 0.97165  Epsilon progress: 0.031500
# | Thread 07 | Step 12614 | Reward: 00  Qmax: 0.0515  Epsilon: 0.96878  Epsilon progress: 0.031535
# | Thread 03 | Step 12930 | Reward: 00  Qmax: 0.0503  Epsilon: 0.97091  Epsilon progress: 0.032325
# | Thread 02 | Step 13030 | Reward: 00  Qmax: 0.0506  Epsilon: 0.98371  Epsilon progress: 0.032575
# | Thread 01 | Step 13194 | Reward: 03  Qmax: 0.0512  Epsilon: 0.98351  Epsilon progress: 0.032985
# | Thread 05 | Step 12834 | Reward: 02  Qmax: 0.0500  Epsilon: 0.98396  Epsilon progress: 0.032085
# | Thread 07 | Step 12838 | Reward: 01  Qmax: 0.0519  Epsilon: 0.96823  Epsilon progress: 0.032095
# | Thread 00 | Step 13469 | Reward: 03  Qmax: 0.0482  Epsilon: 0.96969  Epsilon progress: 0.033673
# | Thread 04 | Step 12944 | Reward: 02  Qmax: 0.0494  Epsilon: 0.96796  Epsilon progress: 0.032360
# | Thread 06 | Step 12872 | Reward: 02  Qmax: 0.0488  Epsilon: 0.97104  Epsilon progress: 0.032180
# | Thread 02 | Step 13198 | Reward: 00  Qmax: 0.0513  Epsilon: 0.98350  Epsilon progress: 0.032995
# | Thread 01 | Step 13413 | Reward: 01  Qmax: 0.0507  Epsilon: 0.98323  Epsilon progress: 0.033532
# | Thread 03 | Step 13283 | Reward: 03  Qmax: 0.0498  Epsilon: 0.97011  Epsilon progress: 0.033208
# | Thread 06 | Step 13038 | Reward: 00  Qmax: 0.0497  Epsilon: 0.97066  Epsilon progress: 0.032595
# | Thread 07 | Step 13056 | Reward: 01  Qmax: 0.0499  Epsilon: 0.96769  Epsilon progress: 0.032640
# | Thread 05 | Step 13097 | Reward: 02  Qmax: 0.0497  Epsilon: 0.98363  Epsilon progress: 0.032743
# | Thread 00 | Step 13715 | Reward: 01  Qmax: 0.0489  Epsilon: 0.96914  Epsilon progress: 0.034287| Thread 02 | Step
#  13408 | Reward: 01  Qmax: 0.0491  Epsilon: 0.98324  Epsilon progress: 0.033520
# | Thread 04 | Step 13183 | Reward: 01  Qmax: 0.0497  Epsilon: 0.96737  Epsilon progress: 0.032958
# | Thread 06 | Step 13209 | Reward: 00  Qmax: 0.0500  Epsilon: 0.97028  Epsilon progress: 0.033023
# | Thread 01 | Step 13636 | Reward: 01  Qmax: 0.0503  Epsilon: 0.98296  Epsilon progress: 0.034090
# | Thread 07 | Step 13251 | Reward: 00  Qmax: 0.0505  Epsilon: 0.96720  Epsilon progress: 0.033127
# | Thread 05 | Step 13303 | Reward: 01  Qmax: 0.0505  Epsilon: 0.98337  Epsilon progress: 0.033258
# | Thread 00 | Step 13892 | Reward: 00  Qmax: 0.0500  Epsilon: 0.96874  Epsilon progress: 0.034730
# | Thread 03 | Step 13597 | Reward: 03  Qmax: 0.0505  Epsilon: 0.96941  Epsilon progress: 0.033993
# | Thread 04 | Step 13419 | Reward: 01  Qmax: 0.0506  Epsilon: 0.96679  Epsilon progress: 0.033548
# | Thread 06 | Step 13384 | Reward: 00  Qmax: 0.0495  Epsilon: 0.96989  Epsilon progress: 0.033460
# | Thread 02 | Step 13758 | Reward: 03  Qmax: 0.0515  Epsilon: 0.98280  Epsilon progress: 0.034395
# | Thread 01 | Step 13902 | Reward: 02  Qmax: 0.0502  Epsilon: 0.98262  Epsilon progress: 0.034755
# | Thread 06 | Step 13554 | Reward: 00  Qmax: 0.0522  Epsilon: 0.96950  Epsilon progress: 0.033885
# | Thread 03 | Step 13859 | Reward: 01  Qmax: 0.0519  Epsilon: 0.96882  Epsilon progress: 0.034647
# | Thread 05 | Step 13614 | Reward: 02  Qmax: 0.0525  Epsilon: 0.98298  Epsilon progress: 0.034035
# | Thread 00 | Step 14222 | Reward: 03  Qmax: 0.0514  Epsilon: 0.96800  Epsilon progress: 0.035555
# | Thread 07 | Step 13627 | Reward: 04  Qmax: 0.0509  Epsilon: 0.96627  Epsilon progress: 0.034068
# | Thread 02 | Step 13965 | Reward: 01  Qmax: 0.0519  Epsilon: 0.98254  Epsilon progress: 0.034912
# | Thread 04 | Step 13754 | Reward: 03  Qmax: 0.0521  Epsilon: 0.96596  Epsilon progress: 0.034385
# | Thread 06 | Step 13725 | Reward: 00  Qmax: 0.0506  Epsilon: 0.96912  Epsilon progress: 0.034313
# | Thread 01 | Step 14207 | Reward: 02  Qmax: 0.0546  Epsilon: 0.98224  Epsilon progress: 0.035518
# | Thread 05 | Step 13889 | Reward: 02  Qmax: 0.0512  Epsilon: 0.98264  Epsilon progress: 0.034723
# | Thread 03 | Step 14169 | Reward: 03  Qmax: 0.0546  Epsilon: 0.96812  Epsilon progress: 0.035423
# | Thread 06 | Step 13900 | Reward: 00  Qmax: 0.0568  Epsilon: 0.96873  Epsilon progress: 0.034750
# | Thread 04 | Step 13973 | Reward: 01  Qmax: 0.0548  Epsilon: 0.96542  Epsilon progress: 0.034932
# | Thread 02 | Step 14223 | Reward: 01  Qmax: 0.0527  Epsilon: 0.98222  Epsilon progress: 0.035557
# | Thread 07 | Step 13937 | Reward: 02  Qmax: 0.0522  Epsilon: 0.96551  Epsilon progress: 0.034842
# | Thread 00 | Step 14596 | Reward: 03  Qmax: 0.0534  Epsilon: 0.96716  Epsilon progress: 0.036490
# | Thread 01 | Step 14480 | Reward: 02  Qmax: 0.0523  Epsilon: 0.98190  Epsilon progress: 0.036200
# | Thread 03 | Step 14343 | Reward: 00  Qmax: 0.0486  Epsilon: 0.96773  Epsilon progress: 0.035858
# | Thread 05 | Step 14072 | Reward: 00  Qmax: 0.0510  Epsilon: 0.98241  Epsilon progress: 0.035180
# | Thread 06 | Step 14077 | Reward: 00  Qmax: 0.0488  Epsilon: 0.96833  Epsilon progress: 0.035193
# | Thread 02 | Step 14411 | Reward: 00  Qmax: 0.0491  Epsilon: 0.98199  Epsilon progress: 0.036027
# | Thread 07 | Step 14104 | Reward: 00  Qmax: 0.0486  Epsilon: 0.96509  Epsilon progress: 0.035260
# | Thread 04 | Step 14291 | Reward: 02  Qmax: 0.0509  Epsilon: 0.96463  Epsilon progress: 0.035728
# | Thread 05 | Step 14299 | Reward: 01  Qmax: 0.0507  Epsilon: 0.98213  Epsilon progress: 0.035748
# | Thread 01 | Step 14742 | Reward: 02  Qmax: 0.0501  Epsilon: 0.98157  Epsilon progress: 0.036855
# | Thread 03 | Step 14609 | Reward: 02  Qmax: 0.0533  Epsilon: 0.96713  Epsilon progress: 0.036522
# | Thread 00 | Step 14931 | Reward: 03  Qmax: 0.0510  Epsilon: 0.96641  Epsilon progress: 0.037327
# | Thread 06 | Step 14385 | Reward: 03  Qmax: 0.0531  Epsilon: 0.96763  Epsilon progress: 0.035963
# | Thread 02 | Step 14766 | Reward: 03  Qmax: 0.0535  Epsilon: 0.98154  Epsilon progress: 0.036915
# | Thread 04 | Step 14537 | Reward: 02  Qmax: 0.0556  Epsilon: 0.96402  Epsilon progress: 0.036342
# | Thread 01 | Step 14905 | Reward: 00  Qmax: 0.0559  Epsilon: 0.98137  Epsilon progress: 0.037262
# | Thread 07 | Step | Thread 05 | Step 1446814524 | Reward: 01   Qmax: 0.0560| Reward: 03   Epsilon: 0.98185 Qmax: 0.0542   Epsilon progress: 0.036310 Epsilon: 0.96419  Epsilon progress: 0.036170
#
# | Thread 06 | Thread 03 | Step 14547| Step  | Reward: 0014828   Qmax: 0.0521| Reward: 01   Epsilon: 0.96727 Qmax: 0.0529   Epsilon progress: 0.036367 Epsilon: 0.96664
#   Epsilon progress: 0.037070
# | Thread 00 | Step 15203 | Reward: 02  Qmax: 0.0534  Epsilon: 0.96579  Epsilon progress: 0.038007
# | Thread 05 | Step 14711 | Reward: 00  Qmax: 0.0503  Epsilon: 0.98161  Epsilon progress: 0.036777
# | Thread 07 | Step 14664 | Reward: 01  Qmax: 0.0501  Epsilon: 0.96371  Epsilon progress: 0.036660
# | Thread 01 | Step 15138 | Reward: 01  Qmax: 0.0508  Epsilon: 0.98108  Epsilon progress: 0.037845
# | Thread 04 | Step 14778 | Reward: 02  Qmax: 0.0497  Epsilon: 0.96342  Epsilon progress: 0.036945
# | Thread 06 | Step 14717 | Reward: 00  Qmax: 0.0503  Epsilon: 0.96689  Epsilon progress: 0.036792
# | Thread 03 | Step 15013 | Reward: 00  Qmax: 0.0497  Epsilon: 0.96622  Epsilon progress: 0.037533
# | Thread 02 | Step 15048 | Reward: 02  Qmax: 0.0505  Epsilon: 0.98119  Epsilon progress: 0.037620
# | Thread 00 | Step 15438 | Reward: 01  Qmax: 0.0533  Epsilon: 0.96526  Epsilon progress: 0.038595
# | Thread 07 | Step 14842 | Reward: 00  Qmax: 0.0629  Epsilon: 0.96327  Epsilon progress: 0.037105
# ...
# | Thread 01 | Step 406939 | Reward: 04  Qmax: 0.5897  Epsilon: 0.50000  Epsilon progress: 1.017348
# | Thread 03 | Step 407161 | Reward: 02  Qmax: 0.5887  Epsilon: 0.10000  Epsilon progress: 1.017902
# | Thread 07 | Step 406625 | Reward: 00  Qmax: 0.5002  Epsilon: 0.01000  Epsilon progress: 1.016563
# | Thread 05 | Step 406531 | Reward: 02  Qmax: 0.5932  Epsilon: 0.50000  Epsilon progress: 1.016328
# | Thread 01 | Step 407108 | Reward: 00  Qmax: 0.4984  Epsilon: 0.50000  Epsilon progress: 1.017770
# | Thread 04 | Step 406850 | Reward: 02  Qmax: 0.5919  Epsilon: 0.01000  Epsilon progress: 1.017125
# | Thread 03 | Step 407383 | Reward: 00  Qmax: 0.4976  Epsilon: 0.10000  Epsilon progress: 1.018458
# | Thread 02 | Step 406952 | Reward: 01  Qmax: 0.5714  Epsilon: 0.50000  Epsilon progress: 1.017380
# | Thread 06 | Step 406430 | Reward: 01  Qmax: 0.5241  Epsilon: 0.10000  Epsilon progress: 1.016075
# | Thread 00 | Step 406842 | Reward: 03  Qmax: 0.5576  Epsilon: 0.10000  Epsilon progress: 1.017105
# | Thread 05 | Step 406702 | Reward: 00  Qmax: 0.4990  Epsilon: 0.50000  Epsilon progress: 1.016755
# | Thread 02 | Step 407145 | Reward: 00  Qmax: 0.5038  Epsilon: 0.50000  Epsilon progress: 1.017862
# | Thread 01 | Step 407407 | Reward: 02  Qmax: 0.5873  Epsilon: 0.50000  Epsilon progress: 1.018517
# | Thread 07 | Step 407057 | Reward: 00  Qmax: 0.5000  Epsilon: 0.01000  Epsilon progress: 1.017643
# | Thread 05 | Step 406995 | Reward: 02  Qmax: 0.5906  Epsilon: 0.50000  Epsilon progress: 1.017488
# | Thread 06 | Step 406755 | Reward: 01  Qmax: 0.5734  Epsilon: 0.10000  Epsilon progress: 1.016887
# | Thread 04 | Step 407272 | Reward: 02  Qmax: 0.5614  Epsilon: 0.01000  Epsilon progress: 1.018180
# | Thread 00 | Step 407201 | Reward: 03  Qmax: 0.5657  Epsilon: 0.10000  Epsilon progress: 1.018002
# | Thread 02 | Step 407373 | Reward: 01  Qmax: 0.5799  Epsilon: 0.50000  Epsilon progress: 1.018433
# | Thread 01 | Step 407642 | Reward: 01  Qmax: 0.5726  Epsilon: 0.50000  Epsilon progress: 1.019105
# | Thread 06 | Step 406933 | Reward: 00  Qmax: 0.5016  Epsilon: 0.10000  Epsilon progress: 1.017332
# | Thread 03 | Step 407927 | Reward: 05  Qmax: 0.4544  Epsilon: 0.10000  Epsilon progress: 1.019818
# | Thread 04 | Step 407483 | Reward: 00  Qmax: 0.5056  Epsilon: 0.01000  Epsilon progress: 1.018708
# | Thread 05 | Step 407246 | Reward: 01  Qmax: 0.5106  Epsilon: 0.50000  Epsilon progress: 1.018115
# | Thread 00 | Step 407497 | Reward: 02  Qmax: 0.5920  Epsilon: 0.10000  Epsilon progress: 1.018743
# | Thread 02 | Step 407662 | Reward: 02  Qmax: 0.5804  Epsilon: 0.50000  Epsilon progress: 1.019155
# | Thread 07 | Step 407504 | Reward: 04  Qmax: 0.4605  Epsilon: 0.01000  Epsilon progress: 1.018760
# | Thread 01 | Step 407946 | Reward: 02  Qmax: 0.5989  Epsilon: 0.50000  Epsilon progress: 1.019865
# | Thread 03 | Step 408155 | Reward: 00  Qmax: 0.5068  Epsilon: 0.10000  Epsilon progress: 1.020388
# | Thread 06 | Step 407250 | Reward: 02  Qmax: 0.5544  Epsilon: 0.10000  Epsilon progress: 1.018125
# | Thread 04 | Step 407742 | Reward: 01  Qmax: 0.5242  Epsilon: 0.01000  Epsilon progress: 1.019355
# | Thread 05 | Step 407554 | Reward: 02  Qmax: 0.4837  Epsilon: 0.50000  Epsilon progress: 1.018885
# | Thread 02 | Step 407886 | Reward: 01  Qmax: 0.5732  Epsilon: 0.50000  Epsilon progress: 1.019715
# | Thread 03 | Step 408335 | Reward: 00  Qmax: 0.5021  Epsilon: 0.10000  Epsilon progress: 1.020838
# | Thread 01 | Step 408182 | Reward: 01  Qmax: 0.5468  Epsilon: 0.50000  Epsilon progress: 1.020455
# | Thread 00 | Step 407857 | Reward: 03  Qmax: 0.6167  Epsilon: 0.10000  Epsilon progress: 1.019643
# | Thread 07 | Step 407851 | Reward: 02  Qmax: 0.5656  Epsilon: 0.01000  Epsilon progress: 1.019627
# | Thread 02 | Step 408062 | Reward: 00  Qmax: 0.5027  Epsilon: 0.50000  Epsilon progress: 1.020155
# | Thread 01 | Step 408372 | Reward: 00  Qmax: 0.5009  Epsilon: 0.50000  Epsilon progress: 1.020930
# | Thread 06 | Step 407616 | Reward: 04  Qmax: 0.5676  Epsilon: 0.10000  Epsilon progress: 1.019040
# | Thread 05 | Step 407964 | Reward: 04  Qmax: 0.5081  Epsilon: 0.50000  Epsilon progress: 1.019910
# | Thread 04 | Step 408242 | Reward: 05  Qmax: 0.5231  Epsilon: 0.01000  Epsilon progress: 1.020605
# | Thread 02 | Step 408306 | Reward: 01  Qmax: 0.5711  Epsilon: 0.50000  Epsilon progress: 1.020765
# | Thread 00 | Step 408184 | Reward: 01  Qmax: 0.4592  Epsilon: 0.10000  Epsilon progress: 1.020460
# | Thread 07 | Step 408154 | Reward: 02  Qmax: 0.5824  Epsilon: 0.01000  Epsilon progress: 1.020385
# | Thread 01 | Step 408669 | Reward: 02  Qmax: 0.4752  Epsilon: 0.50000  Epsilon progress: 1.021672
# | Thread 06 | Step 407927 | Reward: 01  Qmax: 0.5415  Epsilon: 0.10000  Epsilon progress: 1.019818
# | Thread 03 | Step 408896 | Reward: 05  Qmax: 0.4884  Epsilon: 0.10000  Epsilon progress: 1.022240
# | Thread 02 | Step 408527 | Reward: 00  Qmax: 0.5005  Epsilon: 0.50000  Epsilon progress: 1.021318
# | Thread 05 | Step 408246 | Reward: 02  Qmax: 0.6040  Epsilon: 0.50000  Epsilon progress: 1.020615
# | Thread 07 | Step 408482 | Reward: 02  Qmax: 0.5795  Epsilon: 0.01000  Epsilon progress: 1.021205
# | Thread 05 | Step 408432 | Reward: 00  Qmax: 0.5058  Epsilon: 0.50000  Epsilon progress: 1.021080
# | Thread 03 | Step 409169 | Reward: 01  Qmax: 0.5665  Epsilon: 0.10000  Epsilon progress: 1.022922
# | Thread 06 | Step 408241 | Reward: 01  Qmax: 0.5283  Epsilon: 0.10000  Epsilon progress: 1.020603
# | Thread 02 | Step 408808 | Reward: 02  Qmax: 0.6415  Epsilon: 0.50000  Epsilon progress: 1.022020
# | Thread 00 | Step 408711 | Reward: 04  Qmax: 0.4827  Epsilon: 0.10000  Epsilon progress: 1.021778
# | Thread 04 | Step 408817 | Reward: 02  Qmax: 0.5543  Epsilon: 0.01000  Epsilon progress: 1.022042
# | Thread 01 | Step 409212 | Reward: 06  Qmax: 0.4460  Epsilon: 0.50000  Epsilon progress: 1.023030
# | Thread 07 | Step 408839 | Reward: 02  Qmax: 0.5248  Epsilon: 0.01000  Epsilon progress: 1.022098
# | Thread 03 | Step 409509 | Reward: 01  Qmax: 0.5582  Epsilon: 0.10000  Epsilon progress: 1.023772
# | Thread 02 | Step 409080 | Reward: 01  Qmax: 0.5845  Epsilon: 0.50000  Epsilon progress: 1.022700
# | Thread 05 | Step 408798 | Reward: 03  Qmax: 0.5746  Epsilon: 0.50000  Epsilon progress: 1.021995
# | Thread 00 | Step 408951 | Reward: 00  Qmax: 0.5059  Epsilon: 0.10000  Epsilon progress: 1.022377
# | Thread 06 | Step 408645 | Reward: 04  Qmax: 0.4536  Epsilon: 0.10000  Epsilon progress: 1.021613
# | Thread 04 | Step 409112 | Reward: 01  Qmax: 0.5554  Epsilon: 0.01000  Epsilon progress: 1.022780
# | Thread 03 | Step 409682 | Reward: 00  Qmax: 0.5050  Epsilon: 0.10000  Epsilon progress: 1.024205
# | Thread 05 | Step 409013 | Reward: 01  Qmax: 0.5716  Epsilon: 0.50000  Epsilon progress: 1.022533
# | Thread 07 | Step 409142 | Reward: 02  Qmax: 0.5811  Epsilon: 0.01000  Epsilon progress: 1.022855
# | Thread 01 | Step 409611 | Reward: 04  Qmax: 0.5994  Epsilon: 0.50000  Epsilon progress: 1.024028
# | Thread 00 | Step 409182 | Reward: 01  Qmax: 0.5578  Epsilon: 0.10000  Epsilon progress: 1.022955
# | Thread 02 | Step 409377 | Reward: 02  Qmax: 0.4675  Epsilon: 0.50000  Epsilon progress: 1.023443
# | Thread 06 | Step 408907 | Reward: 00  Qmax: 0.4992  Epsilon: 0.10000  Epsilon progress: 1.022268
# | Thread 03 | Step 409899 | Reward: 01  Qmax: 0.5617  Epsilon: 0.10000  Epsilon progress: 1.024747
# | Thread 04 | Step 409412 | Reward: 02  Qmax: 0.5387  Epsilon: 0.01000  Epsilon progress: 1.023530
# | Thread 05 | Step 409197 | Reward: 00  Qmax: 0.4952  Epsilon: 0.50000  Epsilon progress: 1.022992
# | Thread 00 | Step 409456 | Reward: 00  Qmax: 0.4977  Epsilon: 0.10000  Epsilon progress: 1.023640
# | Thread 02 | Step 409618 | Reward: 02  Qmax: 0.5705  Epsilon: 0.50000  Epsilon progress: 1.024045
# | Thread 07 | Step 409454 | Reward: 02  Qmax: 0.5771  Epsilon: 0.01000  Epsilon progress: 1.023635
# | Thread 01 | Step 409962 | Reward: 03  Qmax: 0.5571  Epsilon: 0.50000  Epsilon progress: 1.024905
# | Thread 05 | Step 409507 | Reward: 02  Qmax: 0.5093  Epsilon: 0.50000  Epsilon progress: 1.023767
# | Thread 03 | Step 410225 | Reward: 00  Qmax: 0.4979  Epsilon: 0.10000  Epsilon progress: 1.025562
# | Thread 06 | Step 409290 | Reward: 02  Qmax: 0.5243  Epsilon: 0.10000  Epsilon progress: 1.023225
# | Thread 02 | Step 409849 | Reward: 01  Qmax: 0.5016  Epsilon: 0.50000  Epsilon progress: 1.024622
# | Thread 04 | Step 409888 | Reward: 03  Qmax: 0.4552  Epsilon: 0.01000  Epsilon progress: 1.024720
# | Thread 05 | Step 409685 | Reward: 00  Qmax: 0.5041  Epsilon: 0.50000  Epsilon progress: 1.024212
# | Thread 00 | Step 409826 | Reward: 02  Qmax: 0.5313  Epsilon: 0.10000  Epsilon progress: 1.024565
# | Thread 07 | Step 409811 | Reward: 02  Qmax: 0.5709  Epsilon: 0.01000  Epsilon progress: 1.024528
# | Thread 01 | Step 410284 | Reward: 02  Qmax: 0.6034  Epsilon: 0.50000  Epsilon progress: 1.025710
# | Thread 02 | Step 410064 | Reward: 01  Qmax: 0.5773  Epsilon: 0.50000  Epsilon progress: 1.025160
# | Thread 03 | Step 410511 | Reward: 02  Qmax: 0.5850  Epsilon: 0.10000  Epsilon progress: 1.026277
# | Thread 06 | Step 409630 | Reward: 03  Qmax: 0.5701  Epsilon: 0.10000  Epsilon progress: 1.024075
# | Thread 04 | Step 410142 | Reward: 01  Qmax: 0.5555  Epsilon: 0.01000  Epsilon progress: 1.025355
# | Thread 01 | Step 410525 | Reward: 01  Qmax: 0.5220  Epsilon: 0.50000  Epsilon progress: 1.026312
# | Thread 00 | Step 410078 | Reward: 02  Qmax: 0.5939  Epsilon: 0.10000  Epsilon progress: 1.025195
# | Thread 07 | Step 410074 | Reward: 02  Qmax: 0.5779  Epsilon: 0.01000  Epsilon progress: 1.025185
# | Thread 03 | Step 410753 | Reward: 01  Qmax: 0.5394  Epsilon: 0.10000  Epsilon progress: 1.026882
# | Thread 05 | Step 410029 | Reward: 03  Qmax: 0.6217  Epsilon: 0.50000  Epsilon progress: 1.025073
# | Thread 02 | Step 410340 | Reward: 02  Qmax: 0.5800  Epsilon: 0.50000  Epsilon progress: 1.025850
# | Thread 06 | Step 409885 | Reward: 00  Qmax: 0.5078  Epsilon: 0.10000  Epsilon progress: 1.024712
# | Thread 01 | Step 410714 | Reward: 00  Qmax: 0.5075  Epsilon: 0.50000  Epsilon progress: 1.026785
# | Thread 04 | Step 410455 | Reward: 03  Qmax: 0.4892  Epsilon: 0.01000  Epsilon progress: 1.026137
# | Thread 05 | Step 410209 | Reward: 00  Qmax: 0.5098  Epsilon: 0.50000  Epsilon progress: 1.025522
# | Thread 07 | Step 410397 | Reward: 02  Qmax: 0.6128  Epsilon: 0.01000  Epsilon progress: 1.025993
# | Thread 00 | Step 410408 | Reward: 00  Qmax: 0.5081  Epsilon: 0.10000  Epsilon progress: 1.026020
# | Thread 03 | Step 411076 | Reward: 02  Qmax: 0.6025  Epsilon: 0.10000  Epsilon progress: 1.027690
# | Thread 02 | Step 410656 | Reward: 03  Qmax: 0.5715  Epsilon: 0.50000  Epsilon progress: 1.026640
# | Thread 01 | Step 411055 | Reward: 03  Qmax: 0.6399  Epsilon: 0.50000  Epsilon progress: 1.027637
# | Thread 06 | Step 410281 | Reward: 03  Qmax: 0.6085  Epsilon: 0.10000  Epsilon progress: 1.025702
# | Thread 02 | Step 410835 | Reward: 00  Qmax: 0.5059  Epsilon: 0.50000  Epsilon progress: 1.027087
# | Thread 00 | Step 410688 | Reward: 00  Qmax: 0.5083  Epsilon: 0.10000  Epsilon progress: 1.026720
# | Thread 04 | Step 410853 | Reward: 02  Qmax: 0.5408  Epsilon: 0.01000  Epsilon progress: 1.027133
# | Thread 05 | Step 410708 | Reward: 05  Qmax: 0.5681  Epsilon: 0.50000  Epsilon progress: 1.026770
# | Thread 03 | Step 411428 | Reward: 01  Qmax: 0.5345  Epsilon: 0.10000  Epsilon progress: 1.028570
# | Thread 01 | Step 411347 | Reward: 02  Qmax: 0.5622  Epsilon: 0.50000  Epsilon progress: 1.028368
# | Thread 02 | Step 411049 | Reward: 01  Qmax: 0.5361  Epsilon: 0.50000  Epsilon progress: 1.027623
# | Thread 07 | Step 410901 | Reward: 03  Qmax: 0.6095  Epsilon: 0.01000  Epsilon progress: 1.027252
# | Thread 06 | Step 410575 | Reward: 01  Qmax: 0.5055  Epsilon: 0.10000  Epsilon progress: 1.026437
# | Thread 00 | Step 411012 | Reward: 02  Qmax: 0.5875  Epsilon: 0.10000  Epsilon progress: 1.027530
# | Thread 02 | Step 411255 | Reward: 00  Qmax: 0.5078  Epsilon: 0.50000  Epsilon progress: 1.028137
# | Thread 01 | Step 411593 | Reward: 01  Qmax: 0.5643  Epsilon: 0.50000  Epsilon progress: 1.028982
# | Thread 05 | Step 411025 | Reward: 03  Qmax: 0.6183  Epsilon: 0.50000  Epsilon progress: 1.027562
# | Thread 03 | Step 411758 | Reward: 02  Qmax: 0.5802  Epsilon: 0.10000  Epsilon progress: 1.029395
# | Thread 00 | Step 411210 | Reward: 00  Qmax: 0.5107  Epsilon: 0.10000  Epsilon progress: 1.028025
# | Thread 04 | Step 411370 | Reward: 03  Qmax: 0.5521  Epsilon: 0.01000  Epsilon progress: 1.028425
# | Thread 06 | Step 410879 | Reward: 02  Qmax: 0.5385  Epsilon: 0.10000  Epsilon progress: 1.027197
# | Thread 02 | Step 411459 | Reward: 00  Qmax: 0.5044  Epsilon: 0.50000  Epsilon progress: 1.028647
# | Thread 07 | Step 411316 | Reward: 01  Qmax: 0.5446  Epsilon: 0.01000  Epsilon progress: 1.028290
# | Thread 01 | Step 411813 | Reward: 00  Qmax: 0.5041  Epsilon: 0.50000  Epsilon progress: 1.029532
# | Thread 03 | Step 412067 | Reward: 02  Qmax: 0.6126  Epsilon: 0.10000  Epsilon progress: 1.030167
# | Thread 05 | Step 411340 | Reward: 02  Qmax: 0.5576  Epsilon: 0.50000  Epsilon progress: 1.028350
# | Thread 00 | Step 411465 | Reward: 01  Qmax: 0.5351  Epsilon: 0.10000  Epsilon progress: 1.028663
# | Thread 02 | Step 411755 | Reward: 02  Qmax: 0.6050  Epsilon: 0.50000  Epsilon progress: 1.029387
# | Thread 06 | Step 411236 | Reward: 03  Qmax: 0.5636  Epsilon: 0.10000  Epsilon progress: 1.028090
# | Thread 04 | Step 411752 | Reward: 04  Qmax: 0.5730  Epsilon: 0.01000  Epsilon progress: 1.029380
# | Thread 01 | Step 412130 | Reward: 03  Qmax: 0.5781  Epsilon: 0.50000  Epsilon progress: 1.030325
# | Thread 05 | Step 411563 | Reward: 01  Qmax: 0.5535  Epsilon: 0.50000  Epsilon progress: 1.028908
# | Thread 07 | Step 411710 | Reward: 04  Qmax: 0.5126  Epsilon: 0.01000  Epsilon progress: 1.029275
# | Thread 02 | Step 411953 | Reward: 00  Qmax: 0.5040  Epsilon: 0.50000  Epsilon progress: 1.029883
# | Thread 03 | Step 412420 | Reward: 03  Qmax: 0.5655  Epsilon: 0.10000  Epsilon progress: 1.031050
# | Thread 00 | Step 411838 | Reward: 02  Qmax: 0.5809  Epsilon: 0.10000  Epsilon progress: 1.029595
# | Thread 01 | Step 412323 | Reward: 00  Qmax: 0.5064  Epsilon: 0.50000  Epsilon progress: 1.030808
# | Thread 07 | Step 411922 | Reward: 01  Qmax: 0.5337  Epsilon: 0.01000  Epsilon progress: 1.029805
# | Thread 05 | Step 411816 | Reward: 01  Qmax: 0.5849  Epsilon: 0.50000  Epsilon progress: 1.029540
# | Thread 04 | Step 412078 | Reward: 00  Qmax: 0.5060  Epsilon: 0.01000  Epsilon progress: 1.030195
# | Thread 00 | Step 412072 | Reward: 00  Qmax: 0.5094  Epsilon: 0.10000  Epsilon progress: 1.030180
# | Thread 06 | Step 411752 | Reward: 04  Qmax: 0.6145  Epsilon: 0.10000  Epsilon progress: 1.029380
# | Thread 02 | Step 412273 | Reward: 03  Qmax: 0.5420  Epsilon: 0.50000  Epsilon progress: 1.030682
# | Thread 01 | Step 412576 | Reward: 02  Qmax: 0.5825  Epsilon: 0.50000  Epsilon progress: 1.031440
# | Thread 03 | Step 412739 | Reward: 01  Qmax: 0.5457  Epsilon: 0.10000  Epsilon progress: 1.031848
# | Thread 07 | Step 412327 | Reward: 03  Qmax: 0.5518  Epsilon: 0.01000  Epsilon progress: 1.030817
# | Thread 00 | Step 412320 | Reward: 01  Qmax: 0.5914  Epsilon: 0.10000  Epsilon progress: 1.030800
# | Thread 01 | Step 412799 | Reward: 01  Qmax: 0.5709  Epsilon: 0.50000  Epsilon progress: 1.031997
# | Thread 02 | Step 412519 | Reward: 01  Qmax: 0.5659  Epsilon: 0.50000  Epsilon progress: 1.031297
# | Thread 05 | Step 412255 | Reward: 04  Qmax: 0.5736  Epsilon: 0.50000  Epsilon progress: 1.030638
# | Thread 06 | Step 412034 | Reward: 01  Qmax: 0.5778  Epsilon: 0.10000  Epsilon progress: 1.030085
# | Thread 03 | Step 413052 | Reward: 02  Qmax: 0.5692  Epsilon: 0.10000  Epsilon progress: 1.032630
# | Thread 04 | Step 412563 | Reward: 04  Qmax: 0.5785  Epsilon: 0.01000  Epsilon progress: 1.031408
# | Thread 02 | Step 412698 | Reward: 00  Qmax: 0.5103  Epsilon: 0.50000  Epsilon progress: 1.031745
# | Thread 01 | Step 412987 | Reward: 00  Qmax: 0.5104  Epsilon: 0.50000  Epsilon progress: 1.032468
# | Thread 00 | Step 412545 | Reward: 01  Qmax: 0.5472  Epsilon: 0.10000  Epsilon progress: 1.031362
# | Thread 05 | Step 412480 | Reward: 01  Qmax: 0.5653  Epsilon: 0.50000  Epsilon progress: 1.031200
