# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
driver = webdriver.Chrome('/Users/jubong/Downloads/chromedriver')
driver.implicitly_wait(3)


def fread(path, mode='r'):
    f = open(path, mode)
    return f
def fwrite(path, mode='a'):
    f = open(path, mode)
    return f
def fclose(f):
    return f.close()

def similarity(text, p):
    text = text.split(' ')
    text.append("journal")
    cnt = 0
    for ti in text:
        if ti in p:
            cnt += 1
    return cnt
read_f = fread('/Users/jubong/Downloads/journal_주봉이형.txt')
write_f = fwrite('/Users/jubong/Downloads/journal_complete.txt')
while True:
    read_line = read_f.readline()
    if read_line == '':
        break

    splited_read_line = read_line.split('title=')

    r = splited_read_line[1][1:-2]
    rsplited = r.split(' ')
    rsplited.append('issn')
    rstr = ''
    for rs in rsplited:
        rstr += rs
        if not rs == rsplited[-1]:
            rstr += '+'
    driver.get('https://www.google.com/search?q={0}&oq={0}&aqs=chrome..69i57.3118j0j4&sourceid=chrome&ie=UTF-8'.format(rstr))
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    notices = soup.select('div.rc')


    for n in notices:
        url = str(n.a).split('"')[1]
        pattern = re.compile(r'(\d{4})-(\d{4})')
        match = pattern.search(n.text)
        if match is not None:
            issn_number = str(match.group())
        else:
            continue
        issn_number = issn_number.strip()
        read_line = read_line.replace("ISSN=''", "ISSN='"+issn_number+"'")
        print(issn_number)
        if len(issn_number) != 0 and ('wikipedia' not in url):
            url = url.strip()
            read_line = read_line.replace("HOMEPAGE=''", "HOMEPAGE='"+url+"'")
            driver_site = driver.get(url)
            driver.implicitly_wait(3)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            title = soup.select('title')
            try:
                publisher = (title[0].text.split('- ')[-1].strip())
                read_line = read_line.replace("PUBLISHER=''", "PUBLISHER='"+publisher+"'")
            except IndexError:
                pass
            notices = soup.select('p')

            ps = list()
            count = list()
            for n in notices:
                #print(n.text)
                #print(similarity(r, str(n.text)))
                ps.append(n.text)
                count.append(similarity(r, str(n.text)))
                #print()
            #print(ps[count.index(max(count))])
            description = ps[count.index(max(count))].strip()
            read_line = read_line.replace("DESCRIPTION=''", "DESCRIPTION='"+description+"'")
            break
    write_f.write(read_line + '\n')        
read_f.close()
write_f.close()
# Out:
# 1873-7005
# 1470-3637
# 0925-1030
# 1880-5981
# 0815-3191
# 1861-9568
# 1935-5149
# 0022-0396
# 0278-5846
# 1068-9508
# 1084-8045
# 0966-6923
# 0277-5395
# 1071-5819
# 0269-7491
# 2076-0760
# 1290-0729
# 1352-8165
# 1098-2418
# 1468-0017
# 0926-3373
# 2470-0010
# 2470-0045
# 0305-7356
# 2469-9926
# 4673-8998
# 1097-0010
# 0885-8950
# 1945-7901
# 0894-1777
# 1479-6821
# 0959-4752
# 1467-8268
# 0042-4900
# 0030-5685
# 2233-7822
# 0920-9964
# 0739-7240
# 0883-5403
# 1880-3989
# 1399-0012
# 2313-3406
# 4799-9953
# 1365-2699
# 0165-7836
# 0997-7538
# 1460-1060
# 0167-9236
# 0734-2829
# 0892-7022
# 0924-3453
# 1365-4802
# 0007-1005
# 0016-8033
# 0886-7798
# 1201-9712
# 1631-0683
# 1435-9448
# 1873-4626
# 1754-7121
# 0032-3861
# 1815-0659
# 1879-2464
# 0102-7638
# 0143-7208
# 1946-3936
# 1460-4582
# 1872-2067
# 0003-0481
# 1979-1980
# 0013-0079
# 1558-4542
# 0309-1740
# 0039-3606
# 1360-2381
# 1754-6834
# 0264-9381
# 0065-1419
# 0022-4650
# 0021-9223
# 0018-9359
# 0018-9359
# 0007-4918
# 0268-8697
# 1544-9173
# 1568-7759
# 1873-5061
# 0140-3664
# 1523-2409
# 2510-1560
# 0026-2714
# 2151-7363
# 1040-8703
# 1961-1963
# 1365-2427
# 1544-9173
# 0040-4411
# 1997-2017
# 1161-0301
# 1432-6981
# 0192-0790
# 0925-5214
# 1946-6242
# 1741-5195
# 0040-5779
# 1122-1151
# 1435-1536
# 1774-0746
# 0277-5395
# 0034-5288
# 1872-0218
# 1742-5468
# 1468-3083
# 0305-7070
# 0305-7070
# 0025-1747
# 1363-4607
# 1095-5143
# 1663-4365
# 1573-2770
# 0009-3084
# 4503-0036
# 0892-1997
# 0149-1423
# 1350-5068
# 1261-1272
# 0031-8248
# 1876-6102
# 0002-9092
# 1557-7392
# 1863-5407
# 1547-0350
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-4bc467d9ec52> in <module>()
#      66             soup = BeautifulSoup(html, 'html.parser')
#      67             title = soup.select('title')
# ---> 68             if not title[0] == '':
#      69                 publisher = (title[0].text.split('- ')[-1].strip())
#      70             read_line = read_line.replace("PUBLISHER=''", "PUBLISHER='"+publisher+"'")
#
# IndexError: list index out of range
